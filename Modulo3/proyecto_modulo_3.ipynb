# %% [markdown]
# # **Código para el Demo Day del módulo 3.**

# %% [markdown]
# ## Limpieza de datos.

# %% [markdown]
# Se monta el drive para los archivos necesarios.

# %%
from google.colab import drive 
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %% [markdown]
# Se importan los librerías necesarias.

# %%
import pandas as pd

# %%
import numpy as np

# %% [markdown]
# Se agregan funciones necesarias para evitar repetir código.

# %%
def deleting_data():
    replacing = ['2-Jan', '3-Jan', '4-Jan', '5-Jan','6-Jan', '8-Jan', '10-Jan',
                 '12-Jan', '16-Jan', '24-Jan', 'Jan-64', 'Jan-32']
    return replacing

# %%
def adding_data():
    replacing = ['2 players', '3 players', '4 players', '5 players', '6 players',
                 '8 players', '10 players', '12 players', '16 players',
                 '24 players', '64 players', '32 players']
    return replacing

# %%
def reading_db():
    db = '/content/drive/MyDrive/colab_bedu/proyecto_bedu/games-data-exp.csv'
    return db

# %%
def writing_db():
    db = '/content/drive/MyDrive/colab_bedu/proyecto_bedu/games_rewritten.csv'
    return db

# %% [markdown]
# Se suben los datos en un data frame.

# %%
df = pd.read_csv(reading_db(), sep=',')
df.set_index('name')
pd.set_option('display.max_columns', df.shape[0] + 1)

# %%
df
# Out:
#                                                name      platform    company  \
# 0              The Legend of Zelda: Ocarina of Time    Nintendo64   Nintendo
# 1                          Tony Hawk's Pro Skater 2   PlayStation       Sony
# 2                               Grand Theft Auto IV  PlayStation3       Sony
# 3                                       SoulCalibur     Dreamcast       SEGA
# 4                               Grand Theft Auto IV       Xbox360  Microsoft
# ...                                             ...           ...        ...
# 17939                        Vroom in the Night Sky        Switch   Nintendo
# 17940           Leisure Suit Larry: Box Office Bust  PlayStation3       Sony
# 17941                                         Yaris       Xbox360  Microsoft
# 17942                     Ride to Hell: Retribution            PC    Desktop
# 17943  Family Party: 30 Great Games Obstacle Arcade          WiiU   Nintendo
#
#            r-date  score user_score               developer  \
# 0      11/23/1998     99        9.1                Nintendo
# 1       9/20/2000     98        7.4  NeversoftEntertainment
# 2       4/29/2008     98        7.6           RockstarNorth
# 3        9/8/1999     98        8.5                   Namco
# 4       4/29/2008     98        7.9           RockstarNorth
# ...           ...    ...        ...                     ...
# 17939    4/5/2017     17        3.1                 Poisoft
# 17940    5/5/2009     17        1.9                  Team17
# 17941  10/10/2007     17        4.3   BackboneEntertainment
# 17942   6/24/2013     16        1.3    Eutechnyx,DeepSilver
# 17943   12/4/2012     11          2             ArtCo.,Ltd.
#
#                                                    genre  \
# 0                               Action Adventure,Fantasy
# 1                       Sports,Alternative,Skateboarding
# 2              Action Adventure,Modern,Modern,Open-World
# 3                                     Action,Fighting,3D
# 4              Action Adventure,Modern,Modern,Open-World
# ...                                                  ...
# 17939                           Sports,Individual,Biking
# 17940  Action Adventure,Adventure,Third-Person,Open-W...
# 17941            Driving,Racing,Arcade,Arcade,Automobile
# 17942  Driving,Modern,Racing,Motorcycle,Motocross,Mod...
# 17943         Miscellaneous,Party,Party,Party / Minigame
#
#                      players  critics  users
# 0                   1 Player       22   5749
# 1                      2-Jan       19    647
# 2                   1 Player       64   3806
# 3                      2-Jan       24    324
# 4                   1 Player       86   3364
# ...                      ...      ...    ...
# 17939  No Online Multiplayer       15    105
# 17940  No Online Multiplayer       11     45
# 17941              2  Online        7    129
# 17942                No info        9    581
# 17943  No Online Multiplayer        8    151
#
# [17944 rows x 11 columns]

# %% [markdown]
# Se checan los valores nulos en el data frame

# %%
print(df.isna().sum(axis=0))
# Out:
# name           0
# platform       0
# company        0
# r-date         0
# score          0
# user_score     0
# developer      0
# genre          0
# players       22
# critics        0
# users          0
# dtype: int64

# %%
df_clean_na = df.copy()
df_clean_na['players'] = df_clean_na['players'].fillna(0)

# %%
print(df_clean_na.isna().sum(axis=0))
# Out:
# name          0
# platform      0
# company       0
# r-date        0
# score         0
# user_score    0
# developer     0
# genre         0
# players       0
# critics       0
# users         0
# dtype: int64

# %% [markdown]
# Vamos a extraer el año de lanzamiento

# %%
df_clean_na['year'] = pd.DatetimeIndex(df_clean_na['r-date']).year
pd.set_option('display.max_columns', df_clean_na.shape[0] + 1)

# %%
df_clean_na.head(5)
# Out:
#                                    name      platform    company      r-date  \
# 0  The Legend of Zelda: Ocarina of Time    Nintendo64   Nintendo  11/23/1998
# 1              Tony Hawk's Pro Skater 2   PlayStation       Sony   9/20/2000
# 2                   Grand Theft Auto IV  PlayStation3       Sony   4/29/2008
# 3                           SoulCalibur     Dreamcast       SEGA    9/8/1999
# 4                   Grand Theft Auto IV       Xbox360  Microsoft   4/29/2008
#
#    score user_score               developer  \
# 0     99        9.1                Nintendo
# 1     98        7.4  NeversoftEntertainment
# 2     98        7.6           RockstarNorth
# 3     98        8.5                   Namco
# 4     98        7.9           RockstarNorth
#
#                                        genre   players  critics  users  year
# 0                   Action Adventure,Fantasy  1 Player       22   5749  1998
# 1           Sports,Alternative,Skateboarding     2-Jan       19    647  2000
# 2  Action Adventure,Modern,Modern,Open-World  1 Player       64   3806  2008
# 3                         Action,Fighting,3D     2-Jan       24    324  1999
# 4  Action Adventure,Modern,Modern,Open-World  1 Player       86   3364  2008

# %% [markdown]
# Vamos a extraer el primer género dentro de la columna "genre" y "developer". Esto para hacer un análisis menos complicado de esta columna. Se extrae la columna y se concatena con el dataframe principal, y se cambia el nombre de la columna que se creó.

# %%
df_genre = df_clean_na['genre'].str.split(',', expand=True)
df_genre_dropped = df_genre.dropna(axis=1, how='any')

# %%
df_genre_dropped.head(5)
# Out:
#                   0
# 0  Action Adventure
# 1            Sports
# 2  Action Adventure
# 3            Action
# 4  Action Adventure

# %%
df_developer = df_clean_na['developer'].str.split(',', expand=True)
df_developer_dropped = df_developer.dropna(axis=1, how='any')

# %%
df_developer_dropped.head(5)
# Out:
#                         0
# 0                Nintendo
# 1  NeversoftEntertainment
# 2           RockstarNorth
# 3                   Namco
# 4           RockstarNorth

# %%
df_2 = pd.concat([df_clean_na, df_genre_dropped], axis=1)
df_2_drop = df_2.drop(columns=['genre'])
df_2_renamed = df_2_drop.rename(columns={
    'r-date': 'release_date',
    0: 'genre'
})

# %%
df_2_renamed
# Out:
#                                                name      platform    company  \
# 0              The Legend of Zelda: Ocarina of Time    Nintendo64   Nintendo
# 1                          Tony Hawk's Pro Skater 2   PlayStation       Sony
# 2                               Grand Theft Auto IV  PlayStation3       Sony
# 3                                       SoulCalibur     Dreamcast       SEGA
# 4                               Grand Theft Auto IV       Xbox360  Microsoft
# ...                                             ...           ...        ...
# 17939                        Vroom in the Night Sky        Switch   Nintendo
# 17940           Leisure Suit Larry: Box Office Bust  PlayStation3       Sony
# 17941                                         Yaris       Xbox360  Microsoft
# 17942                     Ride to Hell: Retribution            PC    Desktop
# 17943  Family Party: 30 Great Games Obstacle Arcade          WiiU   Nintendo
#
#       release_date  score user_score               developer  \
# 0       11/23/1998     99        9.1                Nintendo
# 1        9/20/2000     98        7.4  NeversoftEntertainment
# 2        4/29/2008     98        7.6           RockstarNorth
# 3         9/8/1999     98        8.5                   Namco
# 4        4/29/2008     98        7.9           RockstarNorth
# ...            ...    ...        ...                     ...
# 17939     4/5/2017     17        3.1                 Poisoft
# 17940     5/5/2009     17        1.9                  Team17
# 17941   10/10/2007     17        4.3   BackboneEntertainment
# 17942    6/24/2013     16        1.3    Eutechnyx,DeepSilver
# 17943    12/4/2012     11          2             ArtCo.,Ltd.
#
#                      players  critics  users  year             genre
# 0                   1 Player       22   5749  1998  Action Adventure
# 1                      2-Jan       19    647  2000            Sports
# 2                   1 Player       64   3806  2008  Action Adventure
# 3                      2-Jan       24    324  1999            Action
# 4                   1 Player       86   3364  2008  Action Adventure
# ...                      ...      ...    ...   ...               ...
# 17939  No Online Multiplayer       15    105  2017            Sports
# 17940  No Online Multiplayer       11     45  2009  Action Adventure
# 17941              2  Online        7    129  2007           Driving
# 17942                No info        9    581  2013           Driving
# 17943  No Online Multiplayer        8    151  2012     Miscellaneous
#
# [17944 rows x 12 columns]

# %%
df_3 = pd.concat([df_2_renamed, df_developer_dropped], axis = 1)
df_3_drop = df_3.drop(columns=['developer'])
df_3_renamed_3 = df_3_drop.rename(columns={
    0: 'developer'
})

# %%
df_3_renamed_3.head(5)
# Out:
#                                    name      platform    company release_date  \
# 0  The Legend of Zelda: Ocarina of Time    Nintendo64   Nintendo   11/23/1998
# 1              Tony Hawk's Pro Skater 2   PlayStation       Sony    9/20/2000
# 2                   Grand Theft Auto IV  PlayStation3       Sony    4/29/2008
# 3                           SoulCalibur     Dreamcast       SEGA     9/8/1999
# 4                   Grand Theft Auto IV       Xbox360  Microsoft    4/29/2008
#
#    score user_score   players  critics  users  year             genre  \
# 0     99        9.1  1 Player       22   5749  1998  Action Adventure
# 1     98        7.4     2-Jan       19    647  2000            Sports
# 2     98        7.6  1 Player       64   3806  2008  Action Adventure
# 3     98        8.5     2-Jan       24    324  1999            Action
# 4     98        7.9  1 Player       86   3364  2008  Action Adventure
#
#                 developer
# 0                Nintendo
# 1  NeversoftEntertainment
# 2           RockstarNorth
# 3                   Namco
# 4           RockstarNorth

# %% [markdown]
# Limpiamos los datos de los jugadores mediante las funciones establecidas.

# %%
df_3_renamed_3['players'] = df_3_renamed_3['players'].replace(deleting_data(), adding_data())

# %% [markdown]
# Se recorre el index.

# %%
df_3_renamed_3.index += 1

# %%
df_3_renamed_3
# Out:
#                                                name      platform    company  \
# 1              The Legend of Zelda: Ocarina of Time    Nintendo64   Nintendo
# 2                          Tony Hawk's Pro Skater 2   PlayStation       Sony
# 3                               Grand Theft Auto IV  PlayStation3       Sony
# 4                                       SoulCalibur     Dreamcast       SEGA
# 5                               Grand Theft Auto IV       Xbox360  Microsoft
# ...                                             ...           ...        ...
# 17940                        Vroom in the Night Sky        Switch   Nintendo
# 17941           Leisure Suit Larry: Box Office Bust  PlayStation3       Sony
# 17942                                         Yaris       Xbox360  Microsoft
# 17943                     Ride to Hell: Retribution            PC    Desktop
# 17944  Family Party: 30 Great Games Obstacle Arcade          WiiU   Nintendo
#
#       release_date  score user_score                players  critics  users  \
# 1       11/23/1998     99        9.1               1 Player       22   5749
# 2        9/20/2000     98        7.4              2 players       19    647
# 3        4/29/2008     98        7.6               1 Player       64   3806
# 4         9/8/1999     98        8.5              2 players       24    324
# 5        4/29/2008     98        7.9               1 Player       86   3364
# ...            ...    ...        ...                    ...      ...    ...
# 17940     4/5/2017     17        3.1  No Online Multiplayer       15    105
# 17941     5/5/2009     17        1.9  No Online Multiplayer       11     45
# 17942   10/10/2007     17        4.3              2  Online        7    129
# 17943    6/24/2013     16        1.3                No info        9    581
# 17944    12/4/2012     11          2  No Online Multiplayer        8    151
#
#        year             genre               developer
# 1      1998  Action Adventure                Nintendo
# 2      2000            Sports  NeversoftEntertainment
# 3      2008  Action Adventure           RockstarNorth
# 4      1999            Action                   Namco
# 5      2008  Action Adventure           RockstarNorth
# ...     ...               ...                     ...
# 17940  2017            Sports                 Poisoft
# 17941  2009  Action Adventure                  Team17
# 17942  2007           Driving   BackboneEntertainment
# 17943  2013           Driving               Eutechnyx
# 17944  2012     Miscellaneous                  ArtCo.
#
# [17944 rows x 12 columns]

# %% [markdown]
# Checamos los tipos de datos

# %%
df_3_renamed_3.dtypes
# Out:
# name            object
# platform        object
# company         object
# release_date    object
# score            int64
# user_score      object
# players         object
# critics          int64
# users            int64
# year             int64
# genre           object
# developer       object
# dtype: object

# %% [markdown]
# Necesitamos cambiar el user_score a float y release_date a un formato fecha.

# %%
df_3_renamed_3['user_score'] = df_3_renamed_3['user_score'].replace('tbd', 0)

# %%
df_3_renamed_3['genre'] = df_3_renamed_3['genre'].str.replace('General', 'Action Adventure')

# %%
df_3_renamed_3['genre'] = df_3_renamed_3['genre'].str.replace('Japanese-Style', 'Role-Playing')

# %%
df_3_renamed_3['user_score'] = df_3_renamed_3['user_score'].astype(float)

# %%
conversion = {
    'release_date': 'datetime64[ms]'
}

# %%
df_3_renamed_3 = df_3_renamed_3.astype(conversion)

# %%
df_3_renamed_3.dtypes
# Out:
# name                    object
# platform                object
# company                 object
# release_date    datetime64[ns]
# score                    int64
# user_score             float64
# players                 object
# critics                  int64
# users                    int64
# year                     int64
# genre                   object
# developer               object
# dtype: object

# %%
df_3_renamed_3
# Out:
#                                                name      platform    company  \
# 1              The Legend of Zelda: Ocarina of Time    Nintendo64   Nintendo
# 2                          Tony Hawk's Pro Skater 2   PlayStation       Sony
# 3                               Grand Theft Auto IV  PlayStation3       Sony
# 4                                       SoulCalibur     Dreamcast       SEGA
# 5                               Grand Theft Auto IV       Xbox360  Microsoft
# ...                                             ...           ...        ...
# 17940                        Vroom in the Night Sky        Switch   Nintendo
# 17941           Leisure Suit Larry: Box Office Bust  PlayStation3       Sony
# 17942                                         Yaris       Xbox360  Microsoft
# 17943                     Ride to Hell: Retribution            PC    Desktop
# 17944  Family Party: 30 Great Games Obstacle Arcade          WiiU   Nintendo
#
#       release_date  score  user_score                players  critics  users  \
# 1       1998-11-23     99         9.1               1 Player       22   5749
# 2       2000-09-20     98         7.4              2 players       19    647
# 3       2008-04-29     98         7.6               1 Player       64   3806
# 4       1999-09-08     98         8.5              2 players       24    324
# 5       2008-04-29     98         7.9               1 Player       86   3364
# ...            ...    ...         ...                    ...      ...    ...
# 17940   2017-04-05     17         3.1  No Online Multiplayer       15    105
# 17941   2009-05-05     17         1.9  No Online Multiplayer       11     45
# 17942   2007-10-10     17         4.3              2  Online        7    129
# 17943   2013-06-24     16         1.3                No info        9    581
# 17944   2012-12-04     11         2.0  No Online Multiplayer        8    151
#
#        year             genre               developer
# 1      1998  Action Adventure                Nintendo
# 2      2000            Sports  NeversoftEntertainment
# 3      2008  Action Adventure           RockstarNorth
# 4      1999            Action                   Namco
# 5      2008  Action Adventure           RockstarNorth
# ...     ...               ...                     ...
# 17940  2017            Sports                 Poisoft
# 17941  2009  Action Adventure                  Team17
# 17942  2007           Driving   BackboneEntertainment
# 17943  2013           Driving               Eutechnyx
# 17944  2012     Miscellaneous                  ArtCo.
#
# [17944 rows x 12 columns]

# %% [markdown]
# Renombramos y actualizamos el csv.

# %%
df_rewritten = df_3_renamed_3.copy()
df_rewritten.index.names = ['game_id']

# %%
df_rewritten.to_csv(writing_db(), index=True, header=True)

# %% [markdown]
# ## Análisis de los datos.

# %% [markdown]
# Se ordenan los 10 juegos con mayor número de críticas de la prensa y los jugadores.

# %%
df_rewritten.sort_values('critics', ascending=False).head(10)
# Out:
#                                           name      platform   company  \
# game_id
# 955                   Final Fantasy VII Remake  PlayStation4      Sony
# 2271                         Ghost of Tsushima  PlayStation4      Sony
# 116                     The Last of Us Part II  PlayStation4      Sony
# 70                                  God of War  PlayStation4      Sony
# 1027                       Marvel's Spider-Man  PlayStation4      Sony
# 690                          Horizon Zero Dawn  PlayStation4      Sony
# 4400             Paper Mario: The Origami King        Switch  Nintendo
# 20                         Super Mario Odyssey        Switch  Nintendo
# 164                 Uncharted 4: A Thief's End  PlayStation4      Sony
# 1013     The Legend of Zelda: Link's Awakening        Switch  Nintendo
#
#         release_date  score  user_score                players  critics  \
# game_id
# 955       2020-04-10     87         8.1  No Online Multiplayer      126
# 2271      2020-07-17     83         9.2  No Online Multiplayer      122
# 116       2020-06-19     93         5.7  No Online Multiplayer      121
# 70        2018-04-20     94         9.2  No Online Multiplayer      118
# 1027      2018-09-07     87         8.7  No Online Multiplayer      116
# 690       2017-02-28     89         8.4  No Online Multiplayer      115
# 4400      2020-07-17     80         6.9  No Online Multiplayer      114
# 20        2017-10-27     97         8.9  No Online Multiplayer      113
# 164       2016-05-10     93         8.5              Up to 10       113
# 1013      2019-09-20     87         8.4  No Online Multiplayer      111
#
#           users  year             genre           developer
# game_id
# 955        6405  2020      Role-Playing          SquareEnix
# 2271      17420  2020  Action Adventure         SuckerPunch
# 116      146262  2020  Action Adventure          NaughtyDog
# 70        16298  2018  Action Adventure      SCESantaMonica
# 1027       6051  2018  Action Adventure      InsomniacGames
# 690        9400  2017      Role-Playing           Guerrilla
# 4400       1462  2020      Role-Playing  IntelligentSystems
# 20         5546  2017            Action            Nintendo
# 164       12333  2016  Action Adventure          NaughtyDog
# 1013       1135  2019  Action Adventure            Nintendo

# %%
df_rewritten.sort_values('users', ascending=False).head(10)
# Out:
#                                             name      platform   company  \
# game_id
# 116                       The Last of Us Part II  PlayStation4      Sony
# 14809                     Warcraft III: Reforged            PC   Desktop
# 111                     The Witcher 3: Wild Hunt            PC   Desktop
# 2271                           Ghost of Tsushima  PlayStation4      Sony
# 2952                             Death Stranding  PlayStation4      Sony
# 70                                    God of War  PlayStation4      Sony
# 13       The Legend of Zelda: Breath of the Wild        Switch  Nintendo
# 216                     The Witcher 3: Wild Hunt  PlayStation4      Sony
# 59                     The Last of Us Remastered  PlayStation4      Sony
# 16                         Red Dead Redemption 2  PlayStation4      Sony
#
#         release_date  score  user_score                players  critics  \
# game_id
# 116       2020-06-19     93         5.7  No Online Multiplayer      121
# 14809     2020-01-28     59         0.6     Online Multiplayer       46
# 111       2015-05-18     93         9.4  No Online Multiplayer       32
# 2271      2020-07-17     83         9.2  No Online Multiplayer      122
# 2952      2019-11-08     82         7.3  No Online Multiplayer      111
# 70        2018-04-20     94         9.2  No Online Multiplayer      118
# 13        2017-03-03     97         8.6  No Online Multiplayer      109
# 216       2015-05-19     92         9.2  No Online Multiplayer       79
# 59        2014-07-29     95         9.2               Up to 8        70
# 16        2018-10-26     97         8.4              Up to 32        99
#
#           users  year             genre              developer
# game_id
# 116      146262  2020  Action Adventure             NaughtyDog
# 14809     30532  2020          Strategy  BlizzardEntertainment
# 111       17537  2015        Action RPG     CDProjektRedStudio
# 2271      17420  2020  Action Adventure            SuckerPunch
# 2952      16949  2019            Action      KojimaProductions
# 70        16298  2018  Action Adventure         SCESantaMonica
# 13        15873  2017  Action Adventure               Nintendo
# 216       15749  2015        Action RPG     CDProjektRedStudio
# 59        14563  2014  Action Adventure             NaughtyDog
# 16        14315  2018  Action Adventure          RockstarGames

# %% [markdown]
# Los mejores titulos de TLOZ según la crítica.

# %%
df_zelda = df_rewritten[df_rewritten['name'].str.startswith('The Legend of Zelda')]
df_zelda.sort_values('score', ascending = False)
# Out:
#                                                       name        platform  \
# game_id
# 1                     The Legend of Zelda: Ocarina of Time      Nintendo64
# 13                 The Legend of Zelda: Breath of the Wild          Switch
# 25                 The Legend of Zelda: Breath of the Wild            WiiU
# 35                  The Legend of Zelda: Twilight Princess        GameCube
# 39                     The Legend of Zelda: The Wind Waker        GameCube
# 48                 The Legend of Zelda Collector's Edition        GameCube
# 52                 The Legend of Zelda: A Link to the Past  GameBoyAdvance
# 53                      The Legend of Zelda: Majora's Mask      Nintendo64
# 55                  The Legend of Zelda: Twilight Princess             Wii
# 77                 The Legend of Zelda: Ocarina of Time 3D             3DS
# 155                     The Legend of Zelda: Skyward Sword             Wii
# 366             The Legend of Zelda: A Link Between Worlds             3DS
# 309      The Legend of Zelda: Ocarina of Time / Master ...        GameCube
# 417                 The Legend of Zelda: The Wind Waker HD            WiiU
# 421                 The Legend of Zelda: Phantom Hourglass              DS
# 537                  The Legend of Zelda: Majora's Mask 3D             3DS
# 597                    The Legend of Zelda: The Minish Cap  GameBoyAdvance
# 1013                 The Legend of Zelda: Link's Awakening          Switch
# 1074                    The Legend of Zelda: Spirit Tracks              DS
# 1360           The Legend of Zelda: Four Swords Adventures        GameCube
# 1464             The Legend of Zelda: Twilight Princess HD            WiiU
# 1642     The Legend of Zelda: Four Swords Anniversary E...              DS
# 3745     The Legend of Zelda: Breath of the Wild - The ...          Switch
# 5455     The Legend of Zelda: Breath of the Wild - The ...          Switch
# 8398                 The Legend of Zelda: Tri Force Heroes             3DS
#
#           company release_date  score  user_score                players  \
# game_id
# 1        Nintendo   1998-11-23     99         9.1               1 Player
# 13       Nintendo   2017-03-03     97         8.6  No Online Multiplayer
# 25       Nintendo   2017-03-03     96         8.2  No Online Multiplayer
# 35       Nintendo   2006-12-11     96         8.9               1 Player
# 39       Nintendo   2003-03-24     96         9.0               1 Player
# 48       Nintendo   2003-11-17     95         9.0               1 Player
# 52       Nintendo   2002-12-03     95         9.0                No info
# 53       Nintendo   2000-10-25     95         9.2               1 Player
# 55       Nintendo   2006-11-19     95         8.9  No Online Multiplayer
# 77       Nintendo   2011-06-19     94         9.0  No Online Multiplayer
# 155      Nintendo   2011-11-20     93         8.1  No Online Multiplayer
# 366      Nintendo   2013-11-22     91         9.0  No Online Multiplayer
# 309      Nintendo   2003-02-28     91         8.9               1 Player
# 417      Nintendo   2013-09-20     90         9.0  No Online Multiplayer
# 421      Nintendo   2007-10-01     90         8.0                      2
# 537      Nintendo   2015-02-13     89         8.9  No Online Multiplayer
# 597      Nintendo   2005-01-10     89         8.9               1 Player
# 1013     Nintendo   2019-09-20     87         8.4  No Online Multiplayer
# 1074     Nintendo   2009-12-07     87         8.0  No Online Multiplayer
# 1360     Nintendo   2004-06-07     86         7.5              4 players
# 1464     Nintendo   2016-03-04     86         8.5  No Online Multiplayer
# 1642     Nintendo   2011-09-28     85         7.5                No info
# 3745     Nintendo   2017-12-07     81         8.5                No info
# 5455     Nintendo   2017-06-30     78         7.7                No info
# 8398     Nintendo   2015-10-23     73         7.5               Up to 3
#
#          critics  users  year             genre developer
# game_id
# 1             22   5749  1998  Action Adventure  Nintendo
# 13           109  15873  2017  Action Adventure  Nintendo
# 25            13   2245  2017           Fantasy  Nintendo
# 35            16    823  2006  Action Adventure  Nintendo
# 39            80   1370  2003  Action Adventure  Nintendo
# 48             8    194  2003  Action Adventure  Nintendo
# 52            30    524  2002  Action Adventure    Capcom
# 53            27   1198  2000  Action Adventure  Nintendo
# 55            73   2060  2006  Action Adventure  Nintendo
# 77            85   1625  2011     Miscellaneous    GREZZO
# 155           81   2401  2011  Action Adventure  Nintendo
# 366           81   1505  2013        Action RPG  Nintendo
# 309           10    181  2003  Action Adventure  Nintendo
# 417           70   1281  2013  Action Adventure  Nintendo
# 421           57    533  2007  Action Adventure  Nintendo
# 537           82    710  2015           Fantasy    GREZZO
# 597           56    355  2005  Action Adventure  Flagship
# 1013         111   1135  2019  Action Adventure  Nintendo
# 1074          75    315  2009  Action Adventure  Nintendo
# 1360          55    102  2004  Action Adventure  Nintendo
# 1464          74    494  2016  Action Adventure  Tantalus
# 1642          13     73  2011  Action Adventure    GREZZO
# 3745          22    273  2017  Action Adventure  Nintendo
# 5455          15    300  2017  Action Adventure  Nintendo
# 8398          73    219  2015  Action Adventure  Nintendo

# %% [markdown]
# Los mejores juegos de Battlefield según los jugadores.

# %%
df_battlefield = df_rewritten[df_rewritten['name'].str.startswith('Battlefield')]
df_battlefield.sort_values('user_score', ascending = False)
# Out:
#                                              name      platform    company  \
# game_id
# 658                              Battlefield 1942            PC    Desktop
# 796                    Battlefield: Bad Company 2       Xbox360  Microsoft
# 783                    Battlefield: Bad Company 2  PlayStation3       Sony
# 6224            Battlefield 2142: Northern Strike            PC    Desktop
# 340                                 Battlefield 2            PC    Desktop
# 4189                 Battlefield 2: Modern Combat  PlayStation2       Sony
# 974                    Battlefield: Bad Company 2            PC    Desktop
# 876            Battlefield: Bad Company 2 Vietnam  PlayStation3       Sony
# 4341                 Battlefield 2: Modern Combat          Xbox  Microsoft
# 1441           Battlefield: Bad Company 2 Vietnam            PC    Desktop
# 1838                     Battlefield: Bad Company  PlayStation3       Sony
# 903            Battlefield: Bad Company 2 Vietnam       Xbox360  Microsoft
# 680                                 Battlefield 1  PlayStation4       Sony
# 2268                             Battlefield 1943       Xbox360  Microsoft
# 4833     Battlefield 1942: Secret Weapons of WWII            PC    Desktop
# 2016                             Battlefield 1943  PlayStation3       Sony
# 6196                Battlefield 2: Special Forces            PC    Desktop
# 2636                     Battlefield: Bad Company       Xbox360  Microsoft
# 2200           Battlefield 1942: The Road to Rome            PC    Desktop
# 656                                 Battlefield 3            PC    Desktop
# 952                                 Battlefield 1       XboxOne  Microsoft
# 2149                          Battlefield Vietnam            PC    Desktop
# 1931                                Battlefield 3       Xbox360  Microsoft
# 1555                                Battlefield 3  PlayStation3       Sony
# 2629               Battlefield 3: Back to Karkand  PlayStation3       Sony
# 5609                      Battlefield 3: End Game            PC    Desktop
# 1429               Battlefield 3: Back to Karkand            PC    Desktop
# 5828                 Battlefield 2: Modern Combat       Xbox360  Microsoft
# 863                                 Battlefield 1            PC    Desktop
# 1040                  Battlefield 3: Armored Kill            PC    Desktop
# 1522                                Battlefield 4  PlayStation4       Sony
# 8427                Battlefield 3: Close Quarters            PC    Desktop
# 2308               Battlefield 3: Back to Karkand       Xbox360  Microsoft
# 4140                             Battlefield 2142            PC    Desktop
# 9592                    Battlefield 2: Euro Force            PC    Desktop
# 3247                                Battlefield 4            PC    Desktop
# 10803                          Battlefield Heroes            PC    Desktop
# 3892                                Battlefield 4  PlayStation3       Sony
# 4780                                Battlefield 4       Xbox360  Microsoft
# 8780                Battlefield 3: Close Quarters       Xbox360  Microsoft
# 9362                         Battlefield Hardline       XboxOne  Microsoft
# 8146                         Battlefield Hardline  PlayStation4       Sony
# 6519           Battlefield 1: They Shall Not Pass            PC    Desktop
# 4512                  Battlefield 3: Armored Kill  PlayStation3       Sony
# 9623                         Battlefield Hardline            PC    Desktop
# 3668                                Battlefield V            PC    Desktop
# 5235                                Battlefield V       XboxOne  Microsoft
# 8204                                Battlefield V  PlayStation4       Sony
# 11605                      Battlefield: Play4Free            PC    Desktop
#
#         release_date  score  user_score              players  critics  users  \
# game_id
# 658       2002-09-10     89         8.6           64  Online       27    432
# 796       2010-03-02     88         8.6            Up to 24        75    929
# 783       2010-03-02     88         8.5            Up to 24        59    623
# 6224      2007-03-08     77         8.5           64  Online       15     50
# 340       2005-06-21     91         8.4           64  Online       55   1017
# 4189      2005-10-24     80         8.3           32  Online       42     81
# 974       2010-03-02     87         8.2              No info       46   1733
# 876       2010-12-21     88         8.2              No info       16     73
# 4341      2005-10-24     80         8.2           32  Online       49     30
# 1441      2010-12-18     86         8.1              No info       18    217
# 1838      2008-06-23     84         8.1            Up to 24        50    244
# 903       2010-12-21     88         8.0              No info       32    105
# 680       2016-10-18     89         7.9            Up to 64        34   2073
# 2268      2009-07-08     83         7.9           24  Online       65    149
# 4833      2003-09-04     79         7.8           32 players       18     43
# 2016      2009-07-09     84         7.8            Up to 24        40    113
# 6196      2005-11-21     77         7.7           64  Online       25     69
# 2636      2008-06-23     83         7.7            Up to 24        70    286
# 2200      2003-02-02     84         7.6           64 players       22     41
# 656       2011-10-25     89         7.6              No info       61   5302
# 952       2016-10-18     87         7.6            Up to 64        39    701
# 2149      2004-03-14     84         7.6           64 players       48    166
# 1931      2011-10-25     84         7.5              No info       57   2172
# 1555      2011-10-25     85         7.5            Up to 24        38   1843
# 2629      2011-12-06     83         7.5              No info        8     79
# 5609      2013-03-26     78         7.4              No info        9     68
# 1429      2011-12-13     86         7.3              No info        9    167
# 5828      2006-04-11     77         7.2            Up to 24        54     82
# 863       2016-10-21     88         7.1              No info       54   2224
# 1040      2012-09-11     87         7.1              No info       14    116
# 1522      2013-11-12     85         7.1            Up to 64        18   1997
# 8427      2012-06-26     73         6.9              No info        8    127
# 2308      2011-12-13     83         6.9              No info        7     57
# 4140      2006-10-17     80         6.8           64  Online       48    354
# 9592      2006-03-15     71         6.7           64  Online       11     27
# 3247      2013-10-29     81         6.2              No info       52   3821
# 10803     2009-06-25     69         6.1              No info       24    108
# 3892      2013-10-29     80         5.9            Up to 22        14    618
# 4780      2013-10-29     79         5.7            Up to 24        21    560
# 8780      2012-06-26     72         5.5              No info        8     43
# 9362      2015-03-17     71         5.2  Up to more than 64        27    325
# 8146      2015-03-17     73         5.2  Up to more than 64        46    978
# 6519      2017-03-14     76         4.9              No info        8     38
# 4512      2012-09-04     79         4.3              No info        7     78
# 9623      2015-03-17     71         4.2              No info       31    895
# 3668      2018-11-15     81         2.9            Up to 64        52   2814
# 5235      2018-11-15     78         2.9            Up to 64        38    759
# 8204      2018-11-15     73         2.3            Up to 64        23   2542
# 11605     2011-03-10     68         2.0              No info       11    201
#
#          year             genre         developer
# game_id
# 658      2002            Action  DigitalIllusions
# 796      2010            Action            EADICE
# 783      2010            Action            EADICE
# 6224     2007            Action            EADICE
# 340      2005            Action  DigitalIllusions
# 4189     2005            Action  DigitalIllusions
# 974      2010            Action            EADICE
# 876      2010            Action            EADICE
# 4341     2005            Action  DigitalIllusions
# 1441     2010            Action            EADICE
# 1838     2008            Action            EADICE
# 903      2010            Action            EADICE
# 680      2016            Action            EADICE
# 2268     2009            Action     DICEStockholm
# 4833     2003            Action  DigitalIllusions
# 2016     2009            Action     DICEStockholm
# 6196     2005            Action  DigitalIllusions
# 2636     2008            Action            EADICE
# 2200     2003            Action  DigitalIllusions
# 656      2011            Action            EADICE
# 952      2016            Action            EADICE
# 2149     2004            Action  DigitalIllusions
# 1931     2011            Action            EADICE
# 1555     2011            Action            EADICE
# 2629     2011            Action            EADICE
# 5609     2013            Action            EADICE
# 1429     2011            Action            EADICE
# 5828     2006            Action  DigitalIllusions
# 863      2016  Action Adventure            EADICE
# 1040     2012            Action            EADICE
# 1522     2013            Action            EADICE
# 8427     2012            Action            EADICE
# 2308     2011            Action            EADICE
# 4140     2006            Action            EADICE
# 9592     2006            Action  DigitalIllusions
# 3247     2013            Action            EADICE
# 10803    2009            Action            EADICE
# 3892     2013            Action            EADICE
# 4780     2013            Action            EADICE
# 8780     2012            Action            EADICE
# 9362     2015            Modern     VisceralGames
# 8146     2015            Modern     VisceralGames
# 6519     2017            Action            EADICE
# 4512     2012            Action            EADICE
# 9623     2015            Modern     VisceralGames
# 3668     2018            Action            EADICE
# 5235     2018            Action            EADICE
# 8204     2018            Action            EADICE
# 11605    2011            Action  DigitalIllusions

# %% [markdown]
# Juegos que tienen "No Info" en la columna de numero de jugadores

# %%
df_rewritten['players'].value_counts()
# Out:
# No Online Multiplayer    4792
# No info                  4430
# 1 Player                 2032
# 2 players                1212
# 4 players                 962
# Up to 4                   583
# Up to 8                   416
# 2                         402
# 2  Online                 386
# Online Multiplayer        375
# 4  Online                 282
# 8 players                 279
# 8  Online                 209
# Up to 16                  157
# Up to 12                  147
# Up to 6                   135
# Massively Multiplayer     120
# Up to 10                  108
# 16  Online                104
# 16 players                 89
# 6  Online                  69
# 6 players                  63
# 32 players                 41
# 32  Online                 40
# Up to 22                   36
# 10  Online                 35
# Up to 24                   30
# Up to 18                   29
# Up to 20                   28
# 3 players                  27
# 12  Online                 27
# Up to 3                    26
# Up to 32                   25
# Up to 40                   22
# 0                          22
# Up to 5                    21
# Up to 64                   21
# 24  Online                 21
# Up to more than 64         20
# 5 players                  19
# 12 players                 17
# 10 players                 13
# 14  Online                  9
# 64 players                  8
# 5  Online                   8
# 64  Online                  7
# Up to 14                    7
# Up to 9                     5
# 3  Online                   5
# 64+  Online                 5
# Up to 60                    5
# Up to 30                    5
# 44  Online                  4
# 64+                         2
# Up to 36                    1
# 24 players                  1
# Name: players, dtype: int64

# %% [markdown]
# Juegos hechos por desarrollador.

# %%
df_developers_count = df_rewritten['developer'].value_counts()
#df_developers_count_made = pd.DataFrame(df_developers_count, columns = ['developer'])
#pd.set_option('display.max_rows', df_developers_count.shape[0] + 1)
 
df_developers_count
# Out:
# Capcom                                      322
# TelltaleGames                               243
# EASports                                    203
# Nintendo                                    186
# Konami                                      185
# EACanada                                    180
# Ubisoft                                     164
# UbisoftMontreal                             147
# SquareEnix                                  129
# ElectronicArts                              107
# Codemasters                                 104
# OmegaForce                                  101
# EATiburon                                   101
# Sega                                         99
# VisualConcepts                               87
# BandaiNamcoGames                             85
# Traveller'sTales                             82
# VicariousVisions                             77
# Namco                                        71
# Treyarch                                     71
# FromSoftware                                 70
# Midway                                       66
# ArcSystemWorks                               64
# Rebellion                                    64
# Yuke's                                       63
# BioWare                                      63
# Team17                                       62
# GearboxSoftware                              62
# MilestoneS.r.l                               61
# DigitalEclipse                               60
# SonicTeam                                    58
# ArtificialMindandMovement                    57
# WayForward                                   57
# Maxis                                        57
# EurocomEntertainmentSoftware                 55
# ZenStudios                                   54
# NipponIchiSoftware                           53
# ClimaxGroup                                  53
# TTGames                                      52
# HighVoltageSoftware                          52
# SumoDigital                                  51
# NamcoBandaiGames                             51
# HarmonixMusicSystems                         50
# NeversoftEntertainment                       50
# EADICE                                       48
# Level5                                       47
# IoInteractive                                47
# CreativeAssembly                             46
# BackboneEntertainment                        45
# TeamNinja                                    45
# VolitionInc.                                 44
# Cyanide                                      44
# TaitoCorporation                             44
# DONTNODEntertainment                         44
# DoubleFineProductions                        43
# ObsidianEntertainment                        42
# RadicalEntertainment                         42
# TOSE                                         42
# AvalancheSoftware                            41
# CrystalDynamics                              41
# CyberConnect2                                41
# LucasArts                                    41
# KromeStudios                                 40
# Techland                                     40
# BethesdaGameStudios                          40
# Gust                                         40
# FiraxisGames                                 40
# Beenox                                       40
# Atlus                                        39
# BlizzardEntertainment                        39
# IntelligentSystems                           39
# GameFreak                                    39
# Acclaim                                      38
# TerminalReality                              37
# CriterionGames                               37
# DimpsCorporation                             37
# Falcom                                       37
# UbisoftMontpellier                           37
# Koei                                         36
# SaberInteractive                             35
# PandemicStudios                              35
# RainbowStudios                               35
# MonolithProductions                          34
# RareLtd.                                     34
# FrontierDevelopments                         34
# InfinityWard                                 34
# No info                                      33
# ParadoxDevelopmentStudio                     33
# PlatinumGames                                33
# KCET                                         33
# DoubleHelixGames                             32
# idSoftware                                   31
# EALA                                         31
# 3DO                                          30
# EAGames                                      30
# InsomniacGames                               30
# PopCap                                       30
# DaedalicEntertainment                        30
# UbisoftParis                                 30
# ValveSoftware                                30
# SNKPlaymore                                  30
# SCEASanDiegoStudios                          29
# SCEJapanStudio                               29
# SpikeChunsoft                                28
# CompileHeart                                 28
# IntiCreates                                  28
# SCEELondonStudio                             28
# KushGames                                    28
# SonyOnlineEntertainment                      28
# UbisoftShanghai                              28
# AmazeEntertainment                           27
# THQ                                          27
# BlitzGames                                   27
# GriptoniteGames                              27
# SCEA                                         27
# RockstarSanDiego                             27
# Tecmo                                        26
# HeavyIronStudios                             26
# Eutechnyx                                    26
# EARedwoodShores                              26
# RavenSoftware                                25
# HALLabs                                      25
# StainlessGames                               25
# Acquire                                      25
# ArkaneStudios                                25
# MicrosoftGameStudios                         25
# PointofView                                  24
# 989Sports                                    24
# InXileEntertainment                          24
# EdgeofReality                                24
# ToysforBob                                   23
# GrasshopperManufacture                       23
# AvalancheStudios                             23
# Hudson                                       23
# Frogwares                                    23
# WalesInteractiveLtd.                         22
# KoeiTecmoGames                               22
# Kylotonn                                     22
# BizarreCreations                             22
# EpicGames                                    22
# RedStormEntertainment                        22
# Relic                                        21
# Gameloft                                     21
# DigitalExtremes                              21
# IronGalaxyStudios                            21
# EABrightLight                                21
# Spike                                        21
# CityInteractive                              21
# Frozenbyte                                   20
# HBStudiosMultimedia                          20
# SportsInteractive                            20
# SquareSoft                                   20
# ACETeam                                      20
# Activision                                   20
# NinjaTheory                                  20
# ViciousCycle                                 20
# n-Space                                      20
# GameArts                                     20
# RockstarNorth                                20
# RyugaGotokuStudios                           19
# StormfrontStudios                            19
# RemedyEntertainment                          19
# Shin'en                                      19
# Arika                                        19
# LionheadStudios                              19
# KCEJ                                         19
# Crytek                                       19
# Kalypso                                      19
# 11bitstudios                                 19
# MassMedia                                    19
# Starbreeze                                   19
# BethesdaSoftworks                            19
# PipeworksSoftware                            19
# BlooberTeam                                  18
# TwoTribes                                    18
# ArgonautGames                                18
# Z-Axis                                       18
# M2                                           18
# FatsharkAB                                   18
# KojimaProductions                            18
# PivotalGames                                 18
# Treasure                                     18
# MonsterGamesInc.                             18
# CaviaInc.                                    18
# Microids                                     18
# ParadigmEntertainment                        18
# AsoboStudio                                  18
# Funcom                                       18
# BlueTongueEntertainment                      18
# MercurySteam                                 17
# Croteam                                      17
# Bungie                                       17
# Bugbear                                      17
# Housemarque                                  17
# NetherRealmStudios                           17
# NextLevelGames                               17
# ExientEntertainment                          17
# DigitalIllusions                             17
# HudsonSoft                                   17
# Stardock                                     17
# SegaAM2                                      17
# VisceralGames                                17
# 7Studios                                     17
# ZombieStudios                                17
# Tamsoft                                      17
# NivalInteractive                             16
# GaijinEntertainment                          16
# IrrationalGames                              16
# Neverland                                    16
# UbisoftQuebec                                16
# TheSimsStudio                                16
# GRIN                                         16
# Q-Games                                      16
# NaughtyDog                                   16
# HotheadGames                                 16
# HighMoonStudios                              16
# CreatStudios                                 16
# RedLynx                                      16
# RocksteadyStudios                            16
# InfiniteInteractive                          16
# QEntertainment                               16
# Genki                                        16
# BlackBox                                     16
# DrinkBoxStudios                              16
# EidosMontreal                                16
# EtrangesLibellules                           15
# DigitalReality                               15
# CDProjektRedStudio                           15
# SonyInteractiveEntertainment                 15
# SlightlyMadStudios                           15
# Racjin                                       15
# BigBadWolf                                   15
# KleiEntertainment                            15
# SupermassiveGames                            15
# PiranhaBytes                                 15
# 4AGames                                      15
# MassiveEntertainment                         15
# KujuEntertainment                            15
# AbstractionGames                             15
# 4JStudios                                    15
# SparkUnlimited                               15
# Haemimont                                    15
# Tantalus                                     15
# CamelotSoftwarePlanning                      14
# MonolithSoft                                 14
# Atari                                        14
# GSCGameWorld                                 14
# NekoEntertainment                            14
# IdeaFactory                                  14
# Image&Form                                   14
# GaijinGames                                  14
# Natsume                                      14
# TorusGames                                   14
# QuanticDream                                 14
# UbisoftReflections                           14
# Luxoflux                                     14
# NowProduction                                14
# BungieSoftware                               14
# LarianStudiosGames                           14
# JupiterCorporation                           14
# NeocoreGames                                 14
# Mediatonic                                   14
# MachineGames                                 13
# 10tons                                       13
# 2KSports                                     13
# Ganbarion                                    13
# SanzaruGames                                 13
# KINGArt                                      13
# ShabaGames                                   13
# Nicalis                                      13
# Eighting                                     13
# Guerrilla                                    13
# GameRepublic                                 13
# EdenStudios                                  13
# Deck13                                       13
# UbisoftRomania                               13
# BlueCastleGames                              13
# BlackForestGames                             13
# 5pb                                          13
# GunfireGames                                 13
# RevolutionSoftware                           13
# Sting                                        13
# AscaronEntertainmentGmbH                     13
# MediaVision                                  13
# Zoink!                                       12
# BehaviourInteractive                         12
# 5THCell                                      12
# Tri-Ace                                      12
# Hitmaker                                     12
# WowEntertainment                             12
# TimeGateStudios                              12
# BlackOpsEntertainment                        12
# FrictionalGames                              12
# SCEE                                         12
# Page44Studios                                12
# Warthog                                      12
# RespawnEntertainment                         12
# TheOddGentlemen                              12
# FreeRadicalDesign                            12
# BohemiaInteractive                           12
# NixxesSoftware                               12
# AtlusCo.                                     12
# ShinyEntertainment                           12
# RenegadeKid                                  12
# GhostGames                                   12
# EABlackBox                                   12
# SecretLevel                                  12
# TriumphStudios                               12
# RageSoftware                                 12
# FuturLab                                     11
# Wargaming.net                                11
# PyroStudios                                  11
# CoreDesignLtd.                               11
# LiquidEntertainment                          11
# ProjectAces                                  11
# Spiders                                      11
# RealityPump                                  11
# EugenSystems                                 11
# MadDocSoftware                               11
# MonteCristoMultimedia                        11
# CapyGames                                    11
# Hydravision                                  11
# GiantsSoftware                               11
# Opus                                         11
# AttentionToDetail                            11
# Akella                                       11
# 505Games                                     11
# Teyon                                        11
# MatrixSoftware                               11
# SnowblindStudios                             11
# Stoic                                        11
# FirebrandGames                               11
# EnsembleStudios                              11
# HerInteractive                               11
# ZeniMaxMedia                                 11
# AtomicPlanetEntertainment                    11
# SupergiantGames                              11
# SledgehammerGames                            11
# CurveStudios                                 10
# SidheInteractive                             10
# SouthendInteractive                          10
# PolyphonyDigital                             10
# DeckNineGames                                10
# BudCat                                       10
# TheBehemoth                                  10
# TripwireInteractive                          10
# GeniusSonorityInc.                           10
# BigAntStudios                                10
# CoffeeStainStudios                           10
# ZoeMode                                      10
# PenduloStudios                               10
# Aspyr                                        10
# JustAddWater                                 10
# ThunderLotusGames                            10
# TTFusion                                     10
# ZipperInteractive                            10
# VooFooStudios                                10
# YachtClubGames                               10
# AcclaimStudiosCheltenham                     10
# ThreeFieldsEntertainment                     10
# ChunSoft                                     10
# MikeBithell                                  10
# CapcomVancouver                              10
# THQNordic                                    10
# Irem                                         10
# Bandai                                       10
# MarvelousEntertainment                       10
# 1C                                           10
# Day1Studios                                  10
# BossaStudios                                 10
# FrimaStudio                                  10
# GasPoweredGames                              10
# DeadlineGames                                10
# indieszero                                   10
# Virtuos                                      10
# PlaygroundGames                              10
# FreeStyleGames                               10
# KonamiComputerEntertainmentHawaii            10
# Petroglyph                                   10
# BigHugeGames                                  9
# AkiCorp.                                      9
# FarsightStudios                               9
# GripGames                                     9
# ClapHanz                                      9
# BlackIsleStudios                              9
# OtherOceanInteractive                         9
# TheFarm51                                     9
# AccessGames                                   9
# TangoGameworks                                9
# SurrealSoftware                               9
# ReadyatDawn                                   9
# ColdwoodInteractive                           9
# TequilaWorks                                  9
# BluepointGames                                9
# SupersonicSoftware                            9
# Nadeo                                         9
# BlueByte                                      9
# ArtifexMundi                                  9
# CloverStudio                                  9
# LexisNumerique                                9
# HumanHeadStudios                              9
# MaximumGames                                  9
# TarsierStudios                                9
# Artoon                                        9
# 10tonsEntertainment                           9
# ReflectionsInteractive                        9
# ImageEpoch                                    9
# Hangar13                                      9
# HalfbrickStudios                              9
# MarvelousInc.                                 9
# AirtightGames                                 9
# EKOSoftware                                   9
# EAMontreal                                    9
# KheopsStudio                                  9
# Kadokawa                                      9
# HelloGames                                    9
# Xpec                                          9
# WarnerBros.InteractiveEntertainment           9
# LeftFieldProductions                          9
# FlyingWildHog                                 9
# SuckerPunch                                   9
# roll7                                         9
# AirshipSyndicateEntertainment                 9
# EnlightSoftware                               9
# PlaytonicGames                                8
# ToxicGames                                    8
# AlfaSystem                                    8
# 49Games                                       8
# Altron                                        8
# SUPERHOT                                      8
# ChoiceProvisions                              8
# NightSchoolStudio                             8
# MileStoneInc.                                 8
# StrategyFirst                                 8
# Nihilistic                                    8
# ParadoxDevelopment                            8
# VblankEntertainmentInc.                       8
# EvolutionStudios                              8
# TokyoRPGFactory                               8
# Prope                                         8
# JalecoEntertainment                           8
# RedFlyStudio                                  8
# GhostTownGamesLtd.                            8
# RockstarGames                                 8
# RockstarToronto                               8
# FireFlyStudios                                8
# h.a.n.d.Inc.                                  8
# Exakt                                         8
# SCEI                                          8
# Crave                                         8
# GamingMindsStudios                            8
# Saffire                                       8
# NinjaBee                                      8
# SimBin                                        8
# CIGames                                       8
# SonyBend                                      8
# CardboardComputer                             8
# WestwoodStudios                               8
# StudioLiverpool                               8
# RetroStudios                                  8
# AmusementVision                               8
# BitsStudios                                   8
# SensorySweep                                  8
# PlanetMoonStudios                             8
# BlueShift                                     8
# SCESantaMonica                                8
# DeepSilver                                    8
# Sandlot                                       8
# PamDevelopment                                8
# PanicButton                                   8
# TurbineInc.                                   8
# NexEntertainment                              8
# Ambrella                                      8
# ArmatureStudio                                8
# PLAYDEAD                                      8
# DCStudios                                     8
# MoonStudios                                   8
# RitualEntertainment                           8
# LegacyInteractive                             8
# NamcoBandaiGamesAmerica                       8
# Spellbound                                    8
# FinishLineGames                               7
# EASaltLake                                    7
# TributeGames                                  7
# Chucklefish                                   7
# NovaLogic                                     7
# BlitzGamesStudios                             7
# RedBarrels                                    7
# Take-TwoInteractive                           7
# Robomodo                                      7
# AWEGames                                      7
# HaemimontGames                                7
# 3DRealms                                      7
# TeamBondi                                     7
# 10tonsLtd                                     7
# RockstarLeeds                                 7
# KeenGames                                     7
# Introversion                                  7
# IncognitoInc.                                 7
# OutOfTheParkDevelopments                      7
# ParadoxInteractive                            7
# SideQuestStudios                              7
# PaonCorporation                               7
# RazorworksStudios                             7
# NanaOn-Sha                                    7
# LabZeroGames                                  7
# TomorrowCorporation                           7
# PacificCoastPower&Light                       7
# IllFonic                                      7
# SplashDamage                                  7
# MagicPockets                                  7
# SkipLtd.                                      7
# ArenaNet                                      7
# Turn10                                        7
# MidwayStudios-Austin                          7
# TikGames                                      7
# BlackRockStudio                               7
# SmartBombInteractive                          7
# SuperVillainStudios                           7
# Vanillaware                                   7
# HarebrainedSchemesLLC                         7
# SeavenStudio                                  7
# CrawfishInteractive                           7
# IdolMinds                                     7
# WeappyStudio                                  7
# tinyBuild                                     7
# TheGameKitchen                                7
# HeadstrongGames                               7
# BonusXP                                       7
# EAChicago                                     7
# RainGames                                     7
# VigilGames                                    7
# JuiceGames                                    7
# Sobaka                                        7
# KTRacing                                      7
# WideloadGamesInc.                             7
# FuRyu                                         7
# CatDaddyGames                                 7
# Cave                                          7
# ClockStoneSoftware                            7
# Kemco                                         7
# Full-Fat                                      7
# MouldyToofStudios                             7
# HiddenPathEntertainment                       7
# 343Industries                                 7
# DefiantDevelopment                            7
# CodemastersBirmingham                         7
# OverkillSoftware                              7
# CattleCall                                    7
# TwistedPixelGames                             7
# 2KMarin                                       7
# BlitWorks                                     7
# MetalheadSoftware                             7
# DreamFactory                                  7
# OverTheMoon                                   7
# IllusionSoftworks                             7
# CCP                                           7
# Bec                                           7
# GamesFarm                                     7
# PasstechGames                                 6
# BrokenRules                                   6
# Hypnotix                                      6
# ArrowheadGameStudios                          6
# UnitedFrontGames                              6
# TheGameBakers                                 6
# TeamFusion                                    6
# StorminaTeacup                                6
# UberEntertainment                             6
# RobotEntertainment                            6
# BlitzArcade                                   6
# HeadupGames                                   6
# Ratbag                                        6
# MTO                                           6
# AquaPlus                                      6
# AmanitaDesign                                 6
# SNKCorporation                                6
# WebfootTechnologies                           6
# Survios                                       6
# CyanWorlds                                    6
# PapayaStudios                                 6
# CrunchingKoalas                               6
# CauldronLtd.                                  6
# DodgeRoll                                     6
# DisneyInteractiveStudios                      6
# CreaturesInc.                                 6
# Psyonix                                       6
# UbisoftMilan                                  6
# NakedSkyEntertainment                         6
# WadjetEyeGames                                6
# JoWooDEntertainmentAG                         6
# ArtechStudios                                 6
# Good-Feel                                     6
# Razorworks                                    6
# Hi-RezStudios                                 6
# WanakoStudios                                 6
# RockPocketGames                               6
# PropagandaGames                               6
# Stormregion                                   6
# ColossalOrder                                 6
# ZootFly                                       6
# MelbourneHouse                                6
# Pyramid                                       6
# GustoGames                                    6
# SiliconKnights                                6
# UBlartMontpellier                             6
# Headgate                                      6
# MediaMolecule                                 6
# Aspect                                        6
# Helixe                                        6
# VisualImpact                                  6
# AlphadreamCorporation                         6
# UDS                                           6
# Factor5                                       6
# IonStorm                                      6
# Smilebit                                      6
# HexaDrive                                     6
# Virtucraft                                    6
# RelentlessSoftware                            6
# MimimiProductions                             6
# Phantagram                                    6
# OxygenInteractive                             6
# Beamdog                                       6
# NCSOFT                                        6
# Runecraft                                     6
# TotallyGames                                  6
# EngineSoftware                                6
# SlantSix                                      6
# 2KGames                                       6
# IgnitionEntertainment                         6
# ArtePiazza                                    6
# HighImpactGames                               6
# Success                                       6
# inkle                                         6
# 2KCzech                                       6
# SkaStudios                                    6
# HudsonEntertainment                           6
# Shift                                         6
# CellarDoorGames                               6
# Egosoft                                       6
# KCEO                                          6
# Vogster                                       6
# ExperienceInc.                                6
# FeelPlus                                      6
# TrionWorlds                                   6
# UbisoftToronto                                6
# EAVancouver                                   6
# Messhof                                       5
# Ice-PickLodge                                 5
# SNK                                           5
# OwlchemyLabs                                  5
# GratuitousGames                               5
# LimbicEntertainment                           5
# Examu                                         5
# G.Rev                                         5
# TheChineseRoom                                5
# AmplitudeStudios                              5
# BestWay                                       5
# CarbonatedGames                               5
# ONEMORELEVEL                                  5
# nDreams                                       5
# RageSquid                                     5
# Auran                                         5
# AwesomeGamesStudio                            5
# REDEntertainment                              5
# PixelatedMilk                                 5
# ArkedoStudio                                  5
# Darkworks                                     5
# Nfusion                                       5
# TheGentlebros                                 5
# CyberloreStudios                              5
# PressPlay                                     5
# OvertheTopGames                               5
# FullFat                                       5
# NATSUMEATARIInc.                              5
# SMGStudio                                     5
# AcclaimStudiosAustin                          5
# UndeadLabs                                    5
# PeopleCanFly                                  5
# WhitePaperGames                               5
# NordicGamesPublishing                         5
# BreakAwayGames                                5
# Cornfox&Bros.                                 5
# BlackHoleGames                                5
# RunningWithScissors                           5
# PocketStudios                                 5
# ACrowdofMonsters                              5
# KCEStudios                                    5
# EclipseGames                                  5
# MattMakesGamesInc.                            5
# MetanetSoftwareInc.                           5
# CrypticStudios                                5
# TateMultimedia                                5
# Llamasoft                                     5
# DevespressoGames                              5
# NerveSoftware                                 5
# RunicGames                                    5
# WXP                                           5
# SCEJ                                          5
# SerenityForge                                 5
# SpearheadGames                                5
# PatheaGames                                   5
# PipeDreamInteractive                          5
# KochMedia                                     5
# Million                                       5
# OutrageGames                                  5
# EmpireOxford                                  5
# PiranhaGames                                  5
# GrayMatter                                    5
# UppercutGamesPtyLtd                           5
# BlueIsleStudios                               5
# MergeGames                                    5
# VISEntertainment                              5
# InfiniteDreamsInc.                            5
# iNiS                                          5
# QubicGames                                    5
# HotGen                                        5
# SegaSoft                                      5
# BlueFangGames                                 5
# Camel101                                      5
# K2LLC                                         5
# NdCube                                        5
# TitusSoftware                                 5
# OldSchoolGames                                5
# MightandDelight                               5
# UbisoftAnnecy                                 5
# Infogrames                                    5
# DarkEnergyDigital                             5
# RedThreadGames                                5
# FASAStudio                                    5
# RedTribe                                      5
# Lienzo                                        5
# GungHo                                        5
# Vlambeer                                      5
# PopTopSoftware                                5
# PhosphorGamesStudio                           5
# GiantSparrow                                  5
# DMADesign                                     5
# EnhanceGames                                  5
# Marvelous                                     5
# Mossmouth                                     5
# IRGurus                                       5
# CurveDigital                                  5
# EidosInteractive                              5
# StudioSaizensen                               5
# MostWantedEntertainment                       5
# NExTStudios                                   5
# SwingSwingSubmarine                           5
# MojangAB                                      5
# StormindGames                                 5
# Inti                                          5
# Slitherine                                    5
# Bamtang                                       5
# LightWeight                                   5
# CompulsionGames                               5
# RunnerDuck                                    5
# UbisoftSofia                                  5
# Synetic                                       5
# AppaloosaInteractive                          5
# MidwayStudios-SanDiego                        5
# Art                                           5
# 5LivesStudios                                 5
# BonusLevelEntertainment                       4
# 369Interactive                                4
# 3DClouds.it                                   4
# KerberosProductions                           4
# HijinxStudios                                 4
# KrillbiteStudio                               4
# B.B.Studio                                    4
# IMGN.PRO                                      4
# PseudoInteractive                             4
# PillowCastleGames                             4
# IronLoreEntertainment                         4
# GalileaMultimedia                             4
# GlobalA                                       4
# VenomGames                                    4
# BornReadyGames                                4
# MindwareStudios                               4
# HothouseCreations                             4
# AcidWizardStudio                              4
# InevitableEntertainment                       4
# Proletariat                                   4
# SkyboundLLC                                   4
# VarsavGameStudios                             4
# PolyKnightGames                               4
# WinkySoft                                     4
# Sushee                                        4
# WhiteBirdsProductions                         4
# BigBlueBubbleInc.                             4
# CrankyPantsGames                              4
# SunSoft                                       4
# IndieBuilt                                    4
# Mistwalker                                    4
# Coresoft                                      4
# PolygonMagic                                  4
# EpicenterStudios                              4
# VileMonarch                                   4
# UbisoftVancouver                              4
# FrozenCodebase                                4
# SilverCreekEntertainment                      4
# Various                                       4
# LestaStudio                                   4
# AksysGames                                    4
# Destineer                                     4
# SCEStudioCambridge                            4
# Adrenium                                      4
# VirtualToys                                   4
# ReplayStudios                                 4
# Fireglow                                      4
# SpikeChunsoftCo.Ltd.                          4
# MassiveMonster                                4
# Puuba                                         4
# LuckyMountainGames                            4
# BarnhouseEffect                               4
# GearsforBreakfast                             4
# Mediascape                                    4
# Artdink                                       4
# VolatileGames                                 4
# ShiroGames                                    4
# 2XLGames                                      4
# Beatshapers                                   4
# HandyGames                                    4
# EXORStudios                                   4
# TheMolassesFlood                              4
# MumboJumbo                                    4
# MarvelousAQL                                  4
# Question                                      4
# WBGamesMontreal                               4
# NightDiveStudios                              4
# RedBlueGames                                  4
# Camouflaj                                     4
# VertexPop                                     4
# CagedElementInc.                              4
# Moss                                          4
# SportsMogul                                   4
# TiltedMill                                    4
# KaosStudios                                   4
# TaleworldsEntertainment                       4
# SpicyHorse                                    4
# TopWareInteractive                            4
# CremaGames                                    4
# AdrianLazar                                   4
# NumantianGames                                4
# LostToys                                      4
# WarhorseStudios                               4
# KnowWonder                                    4
# Hinterland                                    4
# PhoenixOnlineStudios                          4
# D'AvekkiStudiosLimited                        4
# PlayfulCorp.                                  4
# Yager                                         4
# JugglerGames                                  4
# KeokeNInteractive                             4
# ReflexiveEntertainment                        4
# Ovosonico                                     4
# NineDotsStudio                                4
# Bombservice                                   4
# DigixartEntertainment                         4
# HumanatureStudios                             4
# DigitalFiction                                4
# Doublesix                                     4
# BedtimeDigitalGames                           4
# SoldOut                                       4
# MidwayStudios-LosAngeles                      4
# W!Games                                       4
# IcebergInteractive                            4
# ClimaxEntertainment                           4
# Kaiko                                         4
# TurtleRockStudios                             4
# KungFuFactory                                 4
# EnjoyUpGames                                  4
# CAProduction                                  4
# KaiganGamesOU                                 4
# ArxelTribe                                    4
# FiddlesticksGames                             4
# RogueFactor                                   4
# SamuraiPunk                                   4
# NeonStudios                                   4
# BigbigStudios                                 4
# PurpleLampStudios                             4
# FUNLabs                                       4
# ZoetropeInteractive                           4
# AltarInteractive                              4
# Flight-Plan                                   4
# BrownieBrown                                  4
# PositechGames                                 4
# DeibusStudios                                 4
# LittleGreenMen                                4
# ZeboydGames                                   4
# SkyBoxLabs                                    4
# PiecesInteractive                             4
# Felistella                                    4
# CreativeForgeGames                            4
# TheBeardedLadiesConsulting                    4
# IONLANDS                                      4
# A.C.R.O.N.Y.M.Games                           4
# BrainseedFactory                              4
# PridefulSloth                                 4
# Psikyo                                        4
# LazyBearGames                                 4
# Mitchell                                      4
# CausalBitGames                                4
# NoBrakesGames                                 4
# Playbrains                                    4
# GenuineGames                                  4
# HoneyParadeGames                              4
# GraphicState                                  4
# DeepRed                                       4
# WitchBeam                                     4
# SamBarlow                                     4
# MotionTwin                                    4
# MojoBones                                     4
# Vivarium                                      4
# Otomate                                       4
# PhoenixLabs                                   4
# HorbergProductions                            4
# LookingGlassStudios                           4
# KatauriInteractive                            4
# Eighting/Raizing                              4
# TeamMeat                                      4
# StudioMDHR                                    4
# WiredProductions                              4
# French-Bread                                  4
# MagicDesignStudios                            4
# SteelMantis                                   4
# Simogo                                        4
# SkydanceInteractive                           4
# LinceWorks                                    4
# FDGEntertainment                              4
# VeewoGames                                    4
# NoCode                                        4
# Cing                                          4
# MythicEntertainment                           4
# EdenIndustries                                4
# TheCoalition                                  4
# TheFullbrightCompany                          4
# TheVoxelAgents                                4
# Psygnosis                                     4
# HouseHouse                                    4
# OddworldInhabitants                           4
# RonGilbertandGaryWinnick                      4
# DieGuteFabrik                                 4
# Dennaton                                      4
# HeartMachine                                  4
# UbisoftSanFrancisco                           4
# Flagship                                      4
# FreeLives                                     4
# TerryCavanagh                                 4
# NuFX                                          4
# BootdiskRevolution                            4
# UnknownWorldsEntertainment                    4
# BigApeProductions                             4
# Anchor                                        4
# VillaGorilla                                  4
# FreebirdGames                                 4
# RonimoGames                                   4
# DoubleEleven                                  4
# AsteroidBase                                  4
# ArtPlay                                       4
# PrestoStudios                                 4
# AngelStudios                                  4
# RedHookStudios                                4
# LucidGames                                    4
# Locomalito                                    4
# TwoPointStudios                               4
# CertainAffinity                               4
# TomHapp                                       4
# Banpresto                                     4
# DigitalAnvil                                  4
# AquirisGameStudio                             4
# KunosSimulazioni                              4
# 13AMGames                                     4
# FallenTreeGames                               4
# ReikonGames                                   4
# JoyMasher                                     4
# RedCandleGames                                4
# FlightSchoolStudio                            4
# Lizardcube                                    4
# SCE/WWS                                       4
# PastaGames                                    4
# GREZZO                                        4
# Tri-Crescendo                                 4
# BraceYourselfGames                            4
# NintendoEADTokyo                              4
# PitbullSyndicate                              3
# SegaAM3                                       3
# Playlogic                                     3
# GenePool                                      3
# Suzak                                         3
# MadmindStudio                                 3
# Minds-EyeProductions                          3
# 2KAustralia                                   3
# MadFellowsLtd                                 3
# BlackLabGames                                 3
# TakaraTomy                                    3
# TeamGotham                                    3
# RideonJapan                                   3
# Artematica                                    3
# AI                                            3
# GamesWorkshop                                 3
# FinalStrikeGames                              3
# ...
# NighthawkInteractive                          1
# CrunchTimeGames                               1
# PeakVox                                       1
# IMCGames                                      1
# ReakktorMedia                                 1
# BionicGames                                   1
# InterdimensionalGamesInc                      1
# btfGmbH                                       1
# ArachnidGames                                 1
# NtroniumGames                                 1
# FKDigital                                     1
# Metro                                         1
# OrthogonalGames                               1
# ORiGOGAMES                                    1
# ParityBit                                     1
# GameLife                                      1
# DarkValeGames                                 1
# VladimirKudelka                               1
# FlyingMollusk                                 1
# BinxInteractive                               1
# ChorusWorldwide                               1
# CubeishGames                                  1
# doBell                                        1
# StrictlyLimitedGames                          1
# PyrodactylGames                               1
# Wanadoo                                       1
# MicroApplication                              1
# Bits&Beasts                                   1
# Zoom                                          1
# NosebleedInteractive                          1
# teedoubleuGAMES                               1
# LorenLemcke                                   1
# ShadowTorStudios                              1
# Meyer/GlassInteractive                        1
# Xilam                                         1
# RealtechVR                                    1
# FlyingCafeforSemianimals                      1
# SproutGames                                   1
# CatRabbit                                     1
# PixelStorm                                    1
# Popcannibal                                   1
# aQuadiun                                      1
# Revistonic                                    1
# IguanaBee                                     1
# Poponchi                                      1
# HailstormGamesInc                             1
# BandanaKid                                    1
# ArclightCreations                             1
# Dynamighty                                    1
# HomelessUnicorn                               1
# Prokion                                       1
# StudioSott                                    1
# ConfoundingFactor                             1
# SlipgateStudiosLLC                            1
# FrostwoodInteractive                          1
# SkyshineGames                                 1
# DialogueDesign                                1
# TwoPMStudios                                  1
# RailSimulator.com                             1
# SmallRockets                                  1
# ROIGAMESInc.                                  1
# ArberthStudios                                1
# GameCo                                        1
# DigitalDomain                                 1
# Epics                                         1
# Nucleosys                                     1
# PennyBlackStudios                             1
# OoveeGameStudios                              1
# PlanetInteractive                             1
# iSquaredGames                                 1
# GrendelGames                                  1
# SawflyStudios                                 1
# LorenzoRedaelli                               1
# PuppyPunchProductions                         1
# DeepSpace                                     1
# LaserGuidedGames                              1
# ScrewtapeStudios                              1
# impressionware                                1
# Remode                                        1
# KoeiCanada                                    1
# BillyGoatEntertainmentLtd                     1
# StolenCouchGames                              1
# ImagineerCo.                                  1
# Anim-X                                        1
# ParallelStudio                                1
# Sourcenext                                    1
# MagicSandbox                                  1
# OverGamez                                     1
# MomentumDMT                                   1
# ILMxLab                                       1
# MagikoGaming                                  1
# MikeStudios                                   1
# IntroversionSoftware                          1
# NuevoRetroGames                               1
# CritiqueGaming                                1
# KodiakInteractive                             1
# SomniumGamesd.o.o.                            1
# BloomingBudsStudio                            1
# SpellbindStudios                              1
# CriticalStudio                                1
# StellarVR                                     1
# IOEntertainment                               1
# OxideGames                                    1
# NarcosisTeam                                  1
# BalancingMonkeyGames                          1
# AnimaProject                                  1
# GameGrumps                                    1
# LuckyPause                                    1
# PaxSoftonica                                  1
# RoxorGames                                    1
# Irisloft                                      1
# TanukiiStudios                                1
# HammerfallPublishing                          1
# FastTravelGames                               1
# ValkyrieStudios                               1
# Telenet                                       1
# TomyCorporation                               1
# HonorCode                                     1
# HugeCalfStudios                               1
# WormwoodStudios                               1
# Gambrinous                                    1
# EAJapanStudio                                 1
# DiscordGames                                  1
# Crafts&Meister                                1
# ConvoyGames                                   1
# ThingTrunk                                    1
# StygianSoftware                               1
# TheBaeTeam                                    1
# C.I.N.I.C.Games                               1
# PentadimensionalGames                         1
# RedRocketGames                                1
# Pixwerk                                       1
# CapeCosmic                                    1
# TeamJunkfish                                  1
# IlluminationGames                             1
# Brawsome                                      1
# CardboardBoxEntertainment                     1
# Charybdis                                     1
# SunriseInteractive                            1
# Rekim                                         1
# PalindromeInteractive                         1
# SystemEraSoftworks                            1
# FallenEarth                                   1
# VideoSystem                                   1
# ToeJam&EarlProductions                        1
# Hikergames                                    1
# COWCAT                                        1
# SandboxInteractive                            1
# 2AwesomeStudio                                1
# ReinkoutGames                                 1
# MarvelousFirstStudio                          1
# SpikySnailGamesStudio                         1
# PUBGCorporation                               1
# LionShield                                    1
# XDEV                                          1
# inbetweengames                                1
# BrendonChung                                  1
# ArtifactEntertainment                         1
# Snowhydrallc                                  1
# 1337&SenriLLC                                 1
# Breakfall                                     1
# JunctionPoint                                 1
# NicelyCrafted                                 1
# AsmikAceEntertainment                         1
# LeonardMenchiari                              1
# VagabondDog                                   1
# SoldOutSoftware                               1
# InconspicuousCreations                        1
# JacobAntonucci                                1
# ShiningRockSoftware                           1
# LaPlata                                       1
# BoxedDream                                    1
# OssianStudios                                 1
# PrivateMoonStudios                            1
# IvoryTower                                    1
# Pelikan13                                     1
# Lazy8Studios                                  1
# Hap                                           1
# InstantKingdom                                1
# CubeRoots                                     1
# UltraRunawayGames                             1
# CoconutIslandGames                            1
# TunnelVisionGames                             1
# PunchPunkGames                                1
# Relevo                                        1
# JamesInteractive                              1
# CleverBeans                                   1
# Sacnoth                                       1
# TFLStudios                                    1
# HomebearStudios                               1
# AdhesiveGames                                 1
# WholeHogGames                                 1
# TeamSoho                                      1
# TonsofBits                                    1
# WeirdBeardB.V.                                1
# TKOSoftware                                   1
# ZillionWhales                                 1
# Murudai                                       1
# FrameInteractive                              1
# DifferentTuna                                 1
# FuzzyWuzzyGames                               1
# RockstarVienna                                1
# AstroPort                                     1
# EvanTodd                                      1
# PlatonicPartnership                           1
# InterabangEntertainment                       1
# Neckbolt                                      1
# SomaSim                                       1
# ScreenlifeGames                               1
# ActionSquadStudios                            1
# Team2Bit                                      1
# ElasticGames                                  1
# PeroPeroGames                                 1
# AweInteractive                                1
# DryCactus                                     1
# AlanZucconi                                   1
# InteractiveStone                              1
# Tinimations                                   1
# CatnipGames                                   1
# RobotGentleman                                1
# MuzzyLaneSoftware                             1
# PsycheStudios                                 1
# GameSwing                                     1
# Four5SixPixel                                 1
# VladimirBeletsky                              1
# SpaceMace                                     1
# Blit                                          1
# TomaszWaclawek                                1
# SnapDragonGames                               1
# TinManGames                                   1
# SelectiveIntuition                            1
# ShortbreakStudios                             1
# BadlandGames                                  1
# DragonSlumber                                 1
# TheWorkshop                                   1
# AtomTeam                                      1
# klutzGames                                    1
# VarkianEmpire                                 1
# SnowhoundGames                                1
# TinyHeroGameStudios                           1
# RedEgoGames                                   1
# StellarJockeys                                1
# G-mode                                        1
# Saurus                                        1
# KennyCreanor                                  1
# Nyamyam                                       1
# LongHatHouse                                  1
# CalappaGames                                  1
# StarWraith                                    1
# SundaeMonth                                   1
# RedZeroGames                                  1
# WhoopGroup                                    1
# IceFlames                                     1
# Act3Games                                     1
# ClapfootInc.                                  1
# Denby/Raze                                    1
# Unexpected                                    1
# Universomo                                    1
# RedRedemption                                 1
# StoneLanternGames                             1
# GroundShatterLtd.                             1
# BigFishGames                                  1
# XRGames                                       1
# 8bitGames                                     1
# KonamiComputerEntertainmentNagoya             1
# ZenerWorks                                    1
# KiteGames                                     1
# BlazingBadger                                 1
# OuterloopGames                                1
# JulianLaufer                                  1
# ImageSpaceIncorporated                        1
# FurySoftware                                  1
# OutsiderGames                                 1
# ShadowRage                                    1
# DaybreakGames                                 1
# CurlyMonsters                                 1
# EndgameStudios                                1
# RuffianGames                                  1
# FAKTSoftwareGmBH                              1
# GameTrust                                     1
# ThomasBrush                                   1
# InterwaveStudios                              1
# VEWOInteractiveInc.                           1
# WarnerBros.                                   1
# DestroyerStudios                              1
# SSI                                           1
# LucasLearning                                 1
# TeamGrisGris                                  1
# Nike                                          1
# AccidentalQueens                              1
# IzHard                                        1
# InvestigateNorth                              1
# CavalierGameStudios                           1
# LozangeLab                                    1
# MelbotStudios                                 1
# TraxmasterSoftware                            1
# imaginarylab                                  1
# ImpulseGear                                   1
# 1C:Ino-Co                                     1
# ManaGames                                     1
# BrightsideGames                               1
# TerriVellmann&Doseone                         1
# GeetaGames                                    1
# AterduxEntertainment                          1
# Catch&Release                                 1
# SilesiaGames                                  1
# GameraInteractive                             1
# MoonSpiderStudio                              1
# DoubleBearProductions                         1
# UnfoldGames                                   1
# Straandlooper                                 1
# FlagshipStudios                               1
# It'sAnecdotal                                 1
# SEKOst                                        1
# BarkersCrestStudios                           1
# NEOPOPCORNCorp                                1
# CosmicPicnic                                  1
# PixelCrow                                     1
# UnfinishedPixel                               1
# MacPlay                                       1
# MattBitner                                    1
# PerfectHat                                    1
# Playmind                                      1
# PaintbucketGames                              1
# NinaiGames                                    1
# CranberryStudios                              1
# teamok                                        1
# WeatherFactory                                1
# AlkemiGames                                   1
# Newcom                                        1
# VectorUnit                                    1
# GravityCorporation                            1
# Name: developer, dtype: int64

# %% [markdown]
# Creamos un dataframe para asignar un ID a cada desarrollador. Tammbien eliminamos los duplicados.

# %%
df_only_developers_name = pd.DataFrame(df_rewritten['developer'], columns=['developer'])
df_only_developers_name.index.names = ['developer_ID']
df_only_developers_name
# Out:
#                            developer
# developer_ID
# 1                           Nintendo
# 2             NeversoftEntertainment
# 3                      RockstarNorth
# 4                              Namco
# 5                      RockstarNorth
# ...                              ...
# 17940                        Poisoft
# 17941                         Team17
# 17942          BackboneEntertainment
# 17943                      Eutechnyx
# 17944                         ArtCo.
#
# [17944 rows x 1 columns]

# %%
df_only_developers_name_no_duplicates = df_only_developers_name.groupby('developer').apply(list).reset_index()
df_only_developers_name_no_duplicates.index += 1
df_only_developers_name_no_duplicates = df_only_developers_name_no_duplicates.drop(columns=[0])
df_only_developers_name_no_duplicates.index.names = ['developer_ID']
df_only_developers_name_no_duplicates
# Out:
#                                              developer
# developer_ID
# 1                                         .theprodukkt
# 2                                                 101%
# 3                                       10tacleStudios
# 4                                               10tons
# 5                                  10tonsEntertainment
# 6                                            10tonsLtd
# 7                                         11bitstudios
# 8                                        1337&SenriLLC
# 9                                            13AMGames
# 10                                       14DegreesEast
# 11                                              17-Bit
# 12                                               17Bit
# 13                                                  1C
# 14                                         1C-Softclub
# 15                                           1C:Ino-Co
# 16                                      1C:MaddoxGames
# 17                                     1CEntertainment
# 18                                       1CGameStudios
# 19                              1stPlayableProductions
# 20                                                2015
# 21                                        24CaratGames
# 22                                    258ProductionsAB
# 23                                      2AwesomeStudio
# 24                                           2By3Games
# 25                                               2DBoy
# 26                                          2DawnGames
# 27                                         2KAustralia
# 28                                             2KCzech
# 29                                             2KGames
# 30                                             2KMarin
# 31                                          2KShanghai
# 32                                            2KSports
# 33                                            2XLGames
# 34                                            2x2Games
# 35                                              3000AD
# 36                                       343Industries
# 37                                         34BigThings
# 38                                      369Interactive
# 39                                             3AGames
# 40                                    3D2Entertainment
# 41                                         3DClouds.it
# 42                                                 3DO
# 43                                            3DPeople
# 44                                            3DRealms
# 45                                           3GStudios
# 46                                          3Sprockets
# 47                                            3d6Games
# 48                                       3rdEyeStudios
# 49                                  3rdEyeStudiosOyLTD
# 50                                             49Games
# 51                                             4AGames
# 52                                            4DRulers
# 53                                        4HeadStudios
# 54                                           4JStudios
# 55                                           4XStudios
# 56                                         5-BitsGames
# 57                                              5000ft
# 58                                          5000ftInc.
# 59                                            505Games
# 60                                       5LivesStudios
# 61                                             5THCell
# 62                                                 5pb
# 63                                         6EyesStudio
# 64                                            704Games
# 65                                             7Levels
# 66                                            7Studios
# 67                                            7thChord
# 68                                         8MonkeyLabs
# 69                                           8bitGames
# 70                                        8ing/Raizing
# 71                                           989Sports
# 72                                        @unepic_fran
# 73                                 A.C.R.O.N.Y.M.Games
# 74                                                 A44
# 75                                             ACETeam
# 76                                    ACrowdofMonsters
# 77                                               AGEOD
# 78                                            AGOGames
# 79                                    AHEARTFULOFGAMES
# 80                                                  AI
# 81                                           AIFactory
# 82                                           AOneGames
# 83                                       AQInteractive
# 84                                    ARCEntertainment
# 85                                              AREA35
# 86                                           ARSGOETIA
# 87                                            AWEGames
# 88                                          AbbeyGames
# 89                                           AbrakamSA
# 90                                       AbsolutistLtd
# 91                                    AbstractionGames
# 92                                            Abylight
# 93                                      AbyssGameworks
# 94                                         AccessGames
# 95                                    AccidentalQueens
# 96                                             Acclaim
# 97                                AcclaimStudiosAustin
# 98                            AcclaimStudiosCheltenham
# 99                            AcclaimStudiosManchester
# 100                         AcclaimStudiosSaltLakeCity
# 101                                          AcidNerve
# 102                                   AcidWizardStudio
# 103                                        Ackkstudios
# 104                                            Acquire
# 105                                          Act3Games
# 106                          ActionButtonEntertainment
# 107                                    ActionFormsLtd.
# 108                                 ActionSquadStudios
# 109                                         Activision
# 110                                    ActivisionValue
# 111                                    AdelineSoftware
# 112                                      AdhesiveGames
# 113                                           Adrenium
# 114                                        AdrianLazar
# 115                           AdventurePlanningService
# 116                                       AffableGames
# 117                                          Afterburn
# 118                                             Agenda
# 119                                          AggroCrab
# 120                      AirshipSyndicateEntertainment
# 121                                      AirtightGames
# 122                                       AkaoniStudio
# 123                                             Akella
# 124                                           AkiCorp.
# 125                                         AksysGames
# 126                              AlanHazelden&HarryLee
# 127                                        AlanZucconi
# 128                                      AlawarPremium
# 129                                      AlcachofaSoft
# 130                                          Alchemist
# 131                                           AlexRose
# 132                                         AlfaSystem
# 133                                      AlienAfterAll
# 134                                          Alientrap
# 135                                        AlkemiGames
# 136                                            Allgraf
# 137                                        Allin!Games
# 138                                        AlmostHuman
# 139                                          AlphaUnit
# 140                              AlphadreamCorporation
# 141                                           AltShift
# 142                                   AltarInteractive
# 143                                         AlterGames
# 144                                      AlteredMatter
# 145                                             Altron
# 146                                             Alvion
# 147                                      AmanitaDesign
# 148                                 AmazeEntertainment
# 149                                  AmazonGameStudios
# 150                                              Amble
# 151                                           Ambrella
# 152                                   AmplifyCreations
# 153                                   AmplitudeStudios
# 154                                    AmusementVision
# 155                                              Amuze
# 156                               AnalgesicProductions
# 157                                 AnarchyEnterprises
# 158                                           Anarteam
# 159                                             Anchor
# 160                                            Ancient
# 161                                AndamiroU.S.A.Corp.
# 162                                       AngelStudios
# 163                                      AngryMobGames
# 164                                             Anim-X
# 165                                   AnimaInteractive
# 166                                       AnimaProject
# 167                                      AnimationArts
# 168                                             Ankama
# 169                                        AnkamaGames
# 170                                       AnotherIndie
# 171                                      AnsharStudios
# 172                                       AnsimuzGames
# 173                                         Antagonist
# 174                                    AntimatterGames
# 175                                  AnumanInteractive
# 176                                             ApeLaw
# 177                                            Apeiron
# 178                                     ApogeeSoftware
# 179                                         ApolloSoft
# 180                               AppaloosaInteractive
# 181                                             Appeal
# 182                                            Applava
# 183                       ApplicationSystemsHeidelberg
# 184           ApplicationSystemsHeidelbergSoftwareGmbH
# 185                                        AquaPacific
# 186                                           AquaPlus
# 187                                  AquirisGameStudio
# 188                                             Aquria
# 189                                      ArachnidGames
# 190                                     ArberthStudios
# 191                                     ArcSystemWorks
# 192                                         ArcadeMoon
# 193                                         ArcenGames
# 194                            ArchiactInteractiveLtd.
# 195                                  ArclightCreations
# 196                                           ArenaNet
# 197                                      ArgonautGames
# 198                                              Arika
# 199                                      ArkaneStudios
# 200                                       ArkedoStudio
# 201                                     ArmatureStudio
# 202                                         ArmorGames
# 203                               ArrowheadGameStudios
# 204                                                Art
# 205                                             ArtCo.
# 206                                            ArtPlay
# 207                                         ArtaxGames
# 208                                            Artdink
# 209                                         ArtePiazza
# 210                         ArtechDigitalEntertainment
# 211                                      ArtechStudios
# 212                                    ArtefactsStudio
# 213                                         Artematica
# 214                                          Artifact5
# 215                              ArtifactEntertainment
# 216                                       ArtifexMundi
# 217                                     ArtificeStudio
# 218                          ArtificialMindandMovement
# 219                                  ArtificialStudios
# 220                                         ArtinHeart
# 221                                     ArtisanStudios
# 222                                             Artoon
# 223                         ArvoreImmersiveExperiences
# 224                                         ArxelTribe
# 225                                             Arzest
# 226                                     AsakusaStudios
# 227                           AscaronEntertainmentGmbH
# 228                                   AscensionStudios
# 229                                        AshdarGames
# 230                                          Askiisoft
# 231                              AsmikAceEntertainment
# 232                                            Asobism
# 233                                        AsoboStudio
# 234                                             Aspect
# 235                                              Aspyr
# 236                                        AsterizmCo.
# 237                                       AsteroidBase
# 238                                          AstroPort
# 239                                AsylumEntertainment
# 240                             AsymmetricPublications
# 241                                            AtGames
# 242                                              Atari
# 243                                      AtelierMimina
# 244                               AterduxEntertainment
# 245                 AtlantisInteractiveEntertainment\t
# 246                                              Atlus
# 247                                           AtlusCo.
# 248                                           AtomTeam
# 249                                        AtomicElbow
# 250                                        AtomicGames
# 251                                       AtomicMotion
# 252                          AtomicPlanetEntertainment
# 253                                        AtomicTorch
# 254                                         AtomicWolf
# 255                                           AtooiLLC
# 256                                         AtraxGames
# 257                                  AttentionToDetail
# 258                                      AtypicalGames
# 259                                              Auran
# 260                                     AurelienRegard
# 261                                      AurochDigital
# 262                                          AurumDust
# 263                                         AutumnMoon
# 264                                  AvalancheSoftware
# 265                                   AvalancheStudios
# 266                                        AvalonStyle
# 267                                             Avaria
# 268                                     AweInteractive
# 269                                AwesomeDevelopments
# 270                                 AwesomeGamesStudio
# 271                                    AwesomePlayLtd.
# 272                                     AwesomeStudios
# 273                                 AwfullyNiceStudios
# 274                                            B-Alive
# 275                                         B.B.Studio
# 276                                   BEAUTIFUNGAMESSL
# 277                                      BLGPublishing
# 278                                    BabylonSoftware
# 279                              BackboneCharlottetown
# 280                                 BackboneEmeryville
# 281                              BackboneEntertainment
# 282                                  BackboneVancouver
# 283                             BackwoodsEntertainment
# 284                                   BaconBanditGames
# 285                                  BadFlyInteractive
# 286                                BadHabitProductions
# 287                                       BadlandGames
# 288                               BalancingMonkeyGames
# 289                                   BamEntertainment
# 290                                            Bamtang
# 291                                             Bandai
# 292                                   BandaiNamcoGames
# 293                                         BandanaKid
# 294                                          Banpresto
# 295                                BarkersCrestStudios
# 296                                         BarkingDog
# 297                                           Barnaque
# 298                                    BarnhouseEffect
# 299                                       BaroqueDecay
# 300                                 BatterystapleGames
# 301                                        BattleBorne
# 302                                  BattleGoatStudios
# 303                                    Battlefront.com
# 304                                            Beamdog
# 305                                          BeardEnvy
# 306                                       BeatnikGames
# 307                                        Beatshapers
# 308                                          BeauBlyth
# 309                               BeautifulGameStudios
# 310                                    BeautifulGlitch
# 311                                                Bec
# 312                                        BedlamGames
# 313                                BedtimeDigitalGames
# 314                                           BeeTribe
# 315                                           BeeWorks
# 316                                             Beenox
# 317                                     BeepIndustries
# 318                                    BehaviorStudios
# 319                               BehaviourInteractive
# 320                           BehaviourInteractiveInc.
# 321                                      BeholdStudios
# 322                                     BelugaComputer
# 323                                        BenEsposito
# 324                                      BenedictFritz
# 325                                     BenjaminRivers
# 326                               BeretApplicationsLLC
# 327                                      BerzerkStudio
# 328                                   BestGameEver.com
# 329                                            BestWay
# 330                                          BetaDwarf
# 331                                BethesdaGameStudios
# 332                                  BethesdaSoftworks
# 333                                        BeyondGames
# 334                                              Biart
# 335                                      BigAntStudios
# 336                                  BigApeProductions
# 337                                         BigBadWolf
# 338                                         BigBlueBox
# 339                                  BigBlueBubbleInc.
# 340                                 BigBoatInteractive
# 341                                           BigBoxVR
# 342                                 BigDeezProductions
# 343                                     BigFinishGames
# 344                                       BigFishGames
# 345                                       BigHugeGames
# 346                                       BigJohnGames
# 347                                            BigPark
# 348                                    BigPixelStudios
# 349                          BigRedButtonEntertainment
# 350                                     BigRedSoftware
# 351                                        BigRobotLtd
# 352                                   BigSandwichGames
# 353                                       BigStarGames
# 354                                    BigTimeSoftware
# 355                                  BigbenInteractive
# 356                                      BigbigStudios
# 357                               BigmoonEntertainment
# 358                          BillyGoatEntertainmentLtd
# 359                                    BinxInteractive
# 360                                            BioWare
# 361                                        BionicGames
# 362                                        BishopGames
# 363                                            BitBlot
# 364                                          BitByterz
# 365                                            BitTown
# 366                                         BitboxLtd.
# 367                                       BitmapBureau
# 368                                        Bits&Beasts
# 369                                        BitsStudios
# 370                                   BizarreCreations
# 371                                           BlackBox
# 372                                        BlackCactus
# 373                                       BlackElement
# 374                                   BlackForestGames
# 375                                    BlackHammerGame
# 376                                     BlackHoleGames
# 377                                          BlackInc.
# 378                                   BlackIsleStudios
# 379                                      BlackLabGames
# 380                                BlackLanternStudios
# 381                                   BlackLionStudios
# 382                          BlackMesaModificationTeam
# 383                                  BlackMuffinStudio
# 384                              BlackOpsEntertainment
# 385                                         BlackPants
# 386                                   BlackPantsStudio
# 387                                    BlackRockStudio
# 388                                    BlackSeaStudios
# 389                                      BlackShamrock
# 390                                     BlackShipGames
# 391                                  BlackTowerStudios
# 392                               BlackbirdInteractive
# 393                              BlacklightInteractive
# 394                                     BlackmillGames
# 395                                   BlackpowderGames
# 396                                   BladeInteractive
# 397                                      BlazingBadger
# 398                                     BlazingGriffin
# 399                                      BlazingLizard
# 400                                        BlendoGames
# 401                                   BlindflugStudios
# 402                                               Blit
# 403                                          BlitWorks
# 404                                        BlitzArcade
# 405                                         BlitzGames
# 406                                  BlitzGamesStudios
# 407                              BlizzardEntertainment
# 408                                      BlizzardNorth
# 409                                        BlooberTeam
# 410                                         Bloodirony
# 411                                 BloomingBudsStudio
# 412                                    BlowfishStudios
# 413                                             Blue52
# 414                                    BlueBottleGames
# 415                                           BlueByte
# 416                                    BlueCastleGames
# 417                                      BlueFangGames
# 418                               BlueGiantInteractive
# 419                                    BlueIsleStudios
# 420                                         BlueManchu
# 421                                          BlueOmega
# 422                                 BluePlanetSoftware
# 423                                          BlueShift
# 424                                     BlueSkyStudios
# 425                                         BlueTongue
# 426                            BlueTongueEntertainment
# 427                                  BlueWizardDigital
# 428                                           Bluehole
# 429                                     BlueholeStudio
# 430                                     BluepointGames
# 431                                          Blueshift
# 432                                           Blueside
# 433                                              Blyts
# 434                                 BohemiaInteractive
# 435                                        BojanBrbora
# 436                                  BokuStrategyGames
# 437                                        Bombservice
# 438                                           Boneloaf
# 439                                           Bongfish
# 440                            BonusLevelEntertainment
# 441                                            BonusXP
# 442                                        BoolatGames
# 443                                 BootdiskRevolution
# 444                                      BorealysGames
# 445                                     BornReadyGames
# 446                                    BossGameStudios
# 447                                            BossKey
# 448                                 BossKeyProductions
# 449                                       BossaStudios
# 450                                    BostonAnimation
# 451                          BottleRocketEntertainment
# 452                                         BoxedDream
# 453                                              Bplus
# 454                                 BraceYourselfGames
# 455                                         BrainCandy
# 456                                    BrainSlapStudio
# 457                                      BrainboxGames
# 458                                          Braingame
# 459                                   BrainseedFactory
# 460                                    BrainyStudioLLC
# 461                                        BratDesigns
# 462                                       BraveatNight
# 463                                           Brawsome
# 464                                     BreakAwayGames
# 465                                          Breakfall
# 466                                         Breakpoint
# 467                                       BrendonChung
# 468                                         BrezzaSoft
# 469                                   BrightFutureGmbH
# 470                                    BrightsideGames
# 471                              BroadswordInteractive
# 472                                         Brok3nsite
# 473                                        BrokenRules
# 474                                             Bromio
# 475                                       BrownieBrown
# 476                                           Brownies
# 477                                   BuckshotSoftware
# 478                                             BudCat
# 479                                            Buddiez
# 480                                    BuenaVistaGames
# 481                              BuenaVistaInteractive
# 482                                            Bugbear
# 483                                      BugbombStudio
# 484                                  BukaEntertainment
# 485                                           Bulbware
# 486                                BulkheadInteractive
# 487                                           Bulkypix
# 488                                            Bullets
# 489                                BullfrogProductions
# 490                                     BulwarkStudios
# 491                                        BumbleBeast
# 492                                             Bungie
# 493                                     BungieSoftware
# 494                                 BunkashaPublishing
# 495                                      BurutSoftware
# 496                                        BusyToaster
# 497                            ButterscotchShenanigans
# 498                                         BuzzMonkey
# 499                              ByterunnersGameStudio
# 500                                    C.I.N.I.C.Games
# 501                                       CAProduction
# 502                                        CBEsoftware
# 503                                               CCCP
# 504                                                CCP
# 505                                                CCR
# 506                                 CDProjektRedStudio
# 507                                            CE-Asia
# 508                                 CHUDCHUDINDUSTRIES
# 509                                            CIGames
# 510                                             COWCAT
# 511                                                CRI
# 512                                           CUBETYPE
# 513                                               CXTM
# 514                                            Cadenza
# 515                                   CagedElementInc.
# 516                                       CalappaGames
# 517                                      CaligariGames
# 518                                    CalvinoNoirLtd.
# 519                                           Camel101
# 520                            CamelotSoftwarePlanning
# 521                                          Camouflaj
# 522                                         CampoSanto
# 523                                         CanExplode
# 524                                   Canal+Multimedia
# 525                                      CandygunGames
# 526                                             Capcom
# 527                                 CapcomR&DDivision1
# 528                                    CapcomVancouver
# 529                                         CapeCosmic
# 530                                          CapyGames
# 531                                       CaracalGames
# 532                                           Carapace
# 533                                     CarbineStudios
# 534                                       CarbonStudio
# 535                                    CarbonatedGames
# 536                          CardboardBoxEntertainment
# 537                                  CardboardComputer
# 538                                    CardboardUtopia
# 539                                         CareerSoft
# 540                                     CarlosCoronado
# 541                             CaseyDonnellanGamesLLC
# 542                                        CastlePixel
# 543                                      CatDaddyGames
# 544                                          CatRabbit
# 545                                      Catch&Release
# 546                                        CatnipGames
# 547                                         CattleCall
# 548                                       CauldronLtd.
# 549                                     CausalBitGames
# 550                                     CausticReality
# 551                                CavalierGameStudios
# 552                                               Cave
# 553                                           CaveBarn
# 554                               CavedogEntertainment
# 555                                          CaviaInc.
# 556                                            Celeris
# 557                                    CellarDoorGames
# 558                                 CentauriProduction
# 559                                       CerasusMedia
# 560                                    CertainAffinity
# 561                                 ChainsawesomeGames
# 562                                 ChairEntertainment
# 563                                     ChameleonGames
# 564                                       ChanceAgency
# 565                                           Channel4
# 566                                       ChaosConcept
# 567                                  CharlesUniversity
# 568                                         CharmGames
# 569                                          Charybdis
# 570                                     ChasingCarrots
# 571                                   ChasingRatsGames
# 572                                      CheckSixGames
# 573                                   ChequeredInkLtd.
# 574                                     CherryPopGames
# 575                                          ChessBase
# 576                                             Chibig
# 577                                       ChilledMouse
# 578                                       ChillingoLtd
# 579                                   ChoiceProvisions
# 580                                    ChorusWorldwide
# 581                                        ChrisSawyer
# 582                                     ChromaticGames
# 583                                       ChronicLogic
# 584                                        ChubbyPixel
# 585                                        Chucklefish
# 586                                           ChunSoft
# 587                                             CiRCLE
# 588                                         Cinemaware
# 589                                            Cinemax
# 590                                               Cing
# 591                                      CingularmMode
# 592                                   CinoptStudiosLLC
# 593                                        CipherPrime
# 594                                        CircusFreak
# 595                                    CityInteractive
# 596                                 ClaeysBrothersArts
# 597                                           ClapHanz
# 598                                       ClapfootInc.
# 599                                       Clever-Plays
# 600                                        CleverBeans
# 601                                 ClickEntertainment
# 602                             CliffhangerProductions
# 603                                      ClifftopGames
# 604                                ClimaxEntertainment
# 605                                        ClimaxGroup
# 606                                      ClimaxStudios
# 607                                    ClockDriveGames
# 608                                 ClockStoneSoftware
# 609                                     ClockworkGames
# 610                                     CloudheadGames
# 611                                       CloverStudio
# 612                                   CoatsinkSoftware
# 613                                      CockroachInc.
# 614                                       CocoCucumber
# 615                                       Cococucumber
# 616                                 CoconutIslandGames
# 617                                        CodeAvarice
# 618                                    CodeMysticsInc.
# 619                                           Codeglue
# 620                                        Codemasters
# 621                              CodemastersBirmingham
# 622                                          CodoGames
# 623                               CoffeePoweredMachine
# 624                                 CoffeeStainStudios
# 625                                      CohortStudios
# 626                                          Coilworks
# 627                                  CoinOperatedGames
# 628                                      ColdBeamGames
# 629                                       ColdSymmetry
# 630                                ColdwoodInteractive
# 631                                       ColibriGames
# 632                                   CollectingSmiles
# 633                                   CollisionStudios
# 634                                      ColossalOrder
# 635                                            Compile
# 636                                       CompileHeart
# 637                                    CompulsionGames
# 638                                   ComputerArtworks
# 639                                       ConcernedApe
# 640                                  ConfoundingFactor
# 641                                       ConiferGames
# 642                                      ConnorUllmann
# 643                            ConspiracyEntertainment
# 644                                     ConstantinGraf
# 645                                       Contingent99
# 646                                          Continuum
# 647                            ContrabandEntertainment
# 648                                       ConvictGames
# 649                                        ConvoyGames
# 650                                 CookingMamaLimited
# 651                                        CorbieGames
# 652                                     CoreDesignLtd.
# 653                                 CorecellTechnology
# 654                                           Coresoft
# 655                                        CorneredRat
# 656                                      Cornfox&Bros.
# 657                                       CosmicPicnic
# 658                                            Cosmigo
# 659                                     CosmoscopeGmbH
# 660                                   CounterplayGames
# 661                                  CowardlyCreations
# 662                                        CowboyRodeo
# 663                                      CoyoteConsole
# 664                                 CoyoteDevelopments
# 665                                  CrackedHeadsGames
# 666                                         Crackshell
# 667                                        CradleGames
# 668                                     Crafts&Meister
# 669                                CranberryProduction
# 670                                   CranberryStudios
# 671                                   CrankyPantsGames
# 672                                 CrateEntertainment
# 673                                              Crave
# 674                                CrawfishInteractive
# 675                                         CrazyBunch
# 676                                         CrazyGames
# 677                                 CrazyMonkeyStudios
# 678                                 CrazyVikingStudios
# 679                                          CreSpirit
# 680                                          Crea-Tech
# 681                                       CreatStudios
# 682                                          Creations
# 683                                   CreativeAssembly
# 684                                      CreativeBytes
# 685                               CreativeEdgeSoftware
# 686                                    CreativeEngland
# 687                                 CreativeForgeGames
# 688                                       CreatureLabs
# 689                                      CreaturesInc.
# 690                                             Creazn
# 691                                          CreepyJar
# 692                                         CremaGames
# 693                                  CrescentMoonGames
# 694                                           Crispy's
# 695                                     CriterionGames
# 696                                     CriticalStudio
# 697                                     CritiqueGaming
# 698                             CrocodileEntertainment
# 699                                      Cross-Product
# 700                                            Croteam
# 701                                    CrunchTimeGames
# 702                                    CrunchingKoalas
# 703                                    CryoInteractive
# 704                                     CrypticStudios
# 705                            CryptozoicEntertainment
# 706                                    CrystalDynamics
# 707                                             Crytek
# 708                                   CtrlAltNinjaLtd.
# 709                                     Ctxm/SayDesign
# 710                                          CubeRoots
# 711                                       CubeishGames
# 712                                        CulticGames
# 713                                       CultureBrain
# 714                                CunningDevelopments
# 715                                      CurlyMonsters
# 716                                       CurveDigital
# 717                                  CurveDigitalGames
# 718                                       CurveStudios
# 719                                         CyanWorlds
# 720                                            Cyanide
# 721                                      CyberConnect2
# 722                                  CyberGroupStudios
# 723                                  CyberRhinoStudios
# 724                                   CyberloreStudios
# 725                                          Cybernate
# 726                                        CycloneZero
# 727                                            Cygames
# 728                                      CypronStudios
# 729                                           Cypronia
# 730                             D'AvekkiStudiosLimited
# 731                                        D-PadStudio
# 732                                        D3Publisher
# 733                                          DCStudios
# 734                                         DESTINYbit
# 735                                      DICEStockholm
# 736                                               DICO
# 737                                          DMADesign
# 738                                           DMMGAMES
# 739                                     DNSDevelopment
# 740                               DONTNODEntertainment
# 741                                   DTPEntertainment
# 742                                           DYAGames
# 743                              DaedalicEntertainment
# 744                                 DaedalicStudioWest
# 745                                         DakkoDakko
# 746                                      Dan&GaryGames
# 747                                    DanSmithStudios
# 748                                        DancingDots
# 749                                 DancingDragongames
# 750                                        DangerClose
# 751                                    DanielA.Ramirez
# 752                                 DanielMullinsGames
# 753                                        DanielWynne
# 754                               DapperPenguinStudios
# 755                                  DarkEnergyDigital
# 756                                      DarkSeasGames
# 757                                      DarkStarGames
# 758                                      DarkValeGames
# 759                                          Darkblack
# 760                                       DarklingRoom
# 761                                      DarkwindMedia
# 762                                          Darkworks
# 763                                         DataBecker
# 764                                           DataEast
# 765                                         DataRealms
# 766                                        DaveyWreden
# 767                           DavidA.PalmerProductions
# 768                                       DavidOReilly
# 769                                        Day1Studios
# 770                                      DaybreakGames
# 771                                   DaydreamSoftware
# 772                                           DeadMage
# 773                                     DeadMageStudio
# 774                             DeadToastEntertainment
# 775                                    DeadbeatStudios
# 776                                      DeadlineGames
# 777                                             Deck13
# 778                                      DeckNineGames
# 779                                        DecoDigital
# 780                                     Deconstructeam
# 781                                       Deelinetwork
# 782                             DeepFriedEntertainment
# 783                                            DeepRed
# 784                                        DeepShadows
# 785                                         DeepSilver
# 786                         DeepSilverDambusterStudios
# 787                                          DeepSpace
# 788                                 DefiantDevelopment
# 789                                  DefinitiveStudios
# 790                                      DeibusStudios
# 791                                      DejobaanGames
# 792                                    DeliriumStudios
# 793                      DelphineSoftwareInternational
# 794                                   DelveInteractive
# 795                                          Demimonde
# 796                                    DemiurgeStudios
# 797                                            Demruth
# 798                                         Den-Yu-Sha
# 799                                         Denby/Raze
# 800                                              Denki
# 801                                           Dennaton
# 802                                        DeqafStudio
# 803                                            DerekYu
# 804                                  DesertOwlGamesLLC
# 805                                  DesertProductions
# 806                                DestinationSoftware
# 807                                          Destineer
# 808                                   DestroyerStudios
# 809                               DestructiveCreations
# 810                                           Detalion
# 811                                   DevespressoGames
# 812                                      DevilsDetails
# 813                                    DevolverDigital
# 814                                     DialogueDesign
# 815                                               Dice
# 816                                      DieGuteFabrik
# 817                                      DifferentTuna
# 818                               DigeratiDistribution
# 819                                  DigiFXInteractive
# 820                                       DigitalAnvil
# 821                                       DigitalArrow
# 822                                    DigitalBuilders
# 823                                   DigitalChocolate
# 824                               DigitalConfectioners
# 825                               DigitalCybercherries
# 826                                     DigitalDialect
# 827                                      DigitalDomain
# 828                                      DigitalDreams
# 829                                     DigitalEclipse
# 830                                      DigitalEmbryo
# 831                                    DigitalExtremes
# 832                                     DigitalFiction
# 833                                  DigitalFusionInc.
# 834                                   DigitalHappiness
# 835                                   DigitalIllusions
# 836                                 DigitalLeisureInc.
# 837                                        DigitalLode
# 838                                      DigitalMayhem
# 839                                     DigitalReality
# 840                                DigitalSprayStudios
# 841                                       DigitalTales
# 842                          DigitalWorksEntertainment
# 843                                    DigitaloStudios
# 844                              DigixartEntertainment
# 845                                       DimBulbGames
# 846                                   DimpsCorporation
# 847                                          Dingaling
# 848                                   DinosaurPoloClub
# 849                                  DirectActionGames
# 850                                         DiscoPixel
# 851                                       DiscordGames
# 852                                  DisneyInteractive
# 853                           DisneyInteractiveStudios
# 854                                       DisneyOnline
# 855                                     DissidentLogic
# 856                            DiversionsEntertainment
# 857                                          Division2
# 858                                DoctorEntertainment
# 859                                          DodgeRoll
# 860                                          Doinksoft
# 861                             DoloresEntertainmentSL
# 862                               DoragonEntertainment
# 863                                             DotEmu
# 864                              DoubleBearProductions
# 865                                  DoubleDamageGames
# 866                                   DoubleDutchGames
# 867                                       DoubleEleven
# 868                              DoubleFineProductions
# 869                                   DoubleHelixGames
# 870                                  DoubleZeroOneZero
# ...
# 3272                                     UpperOneGames
# 3273                                 UpperRoomGamesLtd
# 3274                                     UppercutGames
# 3275                               UppercutGamesPtyLtd
# 3276                                    UpstreamArcade
# 3277                                        UrbanGames
# 3278                                     UrniqueStudio
# 3279                                     V1Interactive
# 3280                               V7EntertainmentInc.
# 3281                                            VD-DEV
# 3282                               VEWOInteractiveInc.
# 3283                                  VISEntertainment
# 3284                                            VRESKI
# 3285                                             VSTEP
# 3286                                           VUGames
# 3287                                       VagabondDog
# 3288                               ValhallaGameStudios
# 3289                             ValkyrieEntertainment
# 3290                                   ValkyrieStudios
# 3291                                          ValuSoft
# 3292                                      ValuewaveCo.
# 3293                                     ValveSoftware
# 3294                                          Vanguard
# 3295                                     VanguardGames
# 3296                                       VanillaWare
# 3297                                       Vanillaware
# 3298                                           Vanpool
# 3299                                     VariableState
# 3300                                           Various
# 3301                                     VarkianEmpire
# 3302                                 VarsavGameStudios
# 3303                                             Vatra
# 3304                           VblankEntertainmentInc.
# 3305                                        VectorCell
# 3306                                        VectorUnit
# 3307                                    VectorUnitInc.
# 3308                                        VeewoGames
# 3309                                      Velez&Dubail
# 3310                                VenanEntertainment
# 3311                                        VenomGames
# 3312                              Version2GamesLimited
# 3313                                        VersusEvil
# 3314                                           Vertex4
# 3315                                         VertexPop
# 3316                                      VertigoGames
# 3317                                  VicariousVisions
# 3318                                      ViciousCycle
# 3319                         VictorInteractiveSoftware
# 3320                                       VideoSystem
# 3321                                         Videocult
# 3322                                        VigilGames
# 3323                                       VileMonarch
# 3324                                      VillaGorilla
# 3325                                Vingt-et-unSystems
# 3326                           VirtualAirGuitarCompany
# 3327                                       VirtualToys
# 3328                                        Virtucraft
# 3329                                           Virtuos
# 3330                                     VisceralGames
# 3331                          VisionGamesPublishingLTD
# 3332                                   VisiwareStudios
# 3333                                    VisualConcepts
# 3334                         VisualImaginationSoftware
# 3335                                      VisualImpact
# 3336                                    VisualSciences
# 3337                                   VitaminGStudios
# 3338                                         VivaGames
# 3339                                         VivaMedia
# 3340                                          Vivarium
# 3341                                      VivendiGames
# 3342                                        VividGames
# 3343                                        VividHelix
# 3344                          VixaGames/QubicGamesS.A.
# 3345                                  VladimirBeletsky
# 3346                                VladimirFedyushkin
# 3347                                   VladimirKudelka
# 3348                                          Vlambeer
# 3349                                           Vogster
# 3350                              VogsterEntertainment
# 3351                                 VoidStarCreations
# 3352                                       VoidStudios
# 3353                                     VolatileGames
# 3354                                         Volcanicc
# 3355                                      VolitionInc.
# 3356                                            Voltex
# 3357                                     VooFooStudios
# 3358                                           W!Games
# 3359                                              WARP
# 3360                                   WBGamesMontreal
# 3361                                              WBIE
# 3362                                               WXP
# 3363                                             WZOGI
# 3364                                    WadjetEyeGames
# 3365                              WalesInteractiveLtd.
# 3366                                           Wanadoo
# 3367                                     WanakoStudios
# 3368                                    WarDrumStudios
# 3369                                           Warashi
# 3370                                           Warcave
# 3371                                     Wargaming.net
# 3372                                   WarhorseStudios
# 3373                                     WarmLampGames
# 3374                                       WarnerBros.
# 3375               WarnerBros.InteractiveEntertainment
# 3376                                           Warthog
# 3377                             WastelandsInteractive
# 3378                                        WayForward
# 3379                                WaywardSimulations
# 3380                                        WeAreFuzzy
# 3381                                        WeTheForce
# 3382                                      WeappyStudio
# 3383                                    WeatherFactory
# 3384                               WebfootTechnologies
# 3385                                        WeirdBeard
# 3386                                    WeirdBeardB.V.
# 3387                                   WestwoodStudios
# 3388                                    WhaleRockGames
# 3389                                    WhaleboxStudio
# 3390                             WhiteBirdsProductions
# 3391                                          WhiteElk
# 3392                                   WhiteMoonDreams
# 3393                                         WhiteOwls
# 3394                                   WhitePaperGames
# 3395                            WhiteRabbitInteractive
# 3396                                     WholeHogGames
# 3397                               WholesaleAlgorithms
# 3398                                        WhoopGroup
# 3399                                     WickedStudios
# 3400                                         WideGames
# 3401                              WideRightInteractive
# 3402                                   WideScreenGames
# 3403                                 WideloadGamesInc.
# 3404                                        WildFactor
# 3405                                       WildTangent
# 3406                                   WildfireStudios
# 3407                                              Will
# 3408                                       WillO'Neill
# 3409                              WilliamChyrStudioLLC
# 3410                                  WingsSimulations
# 3411                                         WinkySoft
# 3412                                  WiredProductions
# 3413                                          WishFang
# 3414                                       WishStudios
# 3415                                          Wispfire
# 3416                                         WitchBeam
# 3417                               WitchingHourStudios
# 3418                                          Wizarbox
# 3419                                     WizardFuGames
# 3420                                 WizardsoftheCoast
# 3421                                    WobblyToothLtd
# 3422                                      WolcenStudio
# 3423                                     WolfBrewGames
# 3424                                   WolfpackStudios
# 3425                                 WonderstruckGames
# 3426                                     WoodenMonkeys
# 3427                                           WorkJam
# 3428                                        WorldForge
# 3429                                   WormwoodStudios
# 3430                                  WowEntertainment
# 3431                                  X-RayInteractive
# 3432                                   X.D.NetworkInc.
# 3433                                        X1Software
# 3434                                              XDEV
# 3435                                       XGenStudios
# 3436                                           XLGAMES
# 3437                                           XRGames
# 3438                                           XSGames
# 3439                                    XXVProductions
# 3440                                 XYLAEntertainment
# 3441                                      XaviantGames
# 3442                                            Xendex
# 3443                                    XibalbaStudios
# 3444                                  XicatInteractive
# 3445                                             Xilam
# 3446                                         XonaGames
# 3447                                              Xpec
# 3448                                            Xpiral
# 3449                                              YCJY
# 3450                                         YCJYGames
# 3451                                    YachtClubGames
# 3452                                             Yager
# 3453                                            Yak&Co
# 3454                                       YanimStudio
# 3455                            YippeeEntertainmentLTD
# 3456                                       YoungHorses
# 3457                                         Youxiland
# 3458                                 YoyoEntertainment
# 3459                                             YsNet
# 3460                                       YsbrydGames
# 3461                                            Yuke's
# 3462                        YukitamaCreativeIndustries
# 3463                                   YummyYummyTummy
# 3464                                            Z-Axis
# 3465                                             ZA/UM
# 3466                                       ZANDELMEDIA
# 3467                             ZachtronicsIndustries
# 3468                                            Zallag
# 3469                                             Zaxis
# 3470                                   ZealGameStudios
# 3471                                       ZeboydGames
# 3472                                     ZedTwoLimited
# 3473                                        ZenStudios
# 3474                                        ZenerWorks
# 3475                                           Zengami
# 3476                                      ZeniMaxMedia
# 3477                                        ZenithBlue
# 3478                                      ZeroBitGames
# 3479                                      ZeroSumGames
# 3480                                           Zerodiv
# 3481                                     ZillionWhales
# 3482                                      ZindagiGames
# 3483                                 ZipperInteractive
# 3484                                           ZoeMode
# 3485                               ZoetropeInteractive
# 3486                                            Zoink!
# 3487                                      ZojoiStudios
# 3488                                            Zombie
# 3489                                     ZombieStudios
# 3490                                          ZonoInc.
# 3491                                              Zoom
# 3492                                       ZoonamiLtd.
# 3493                                           ZootFly
# 3494                                            Zordix
# 3495                                      ZordixRacing
# 3496                                            Zuxxez
# 3497                                    [bracket]games
# 3498                                          aQuadiun
# 3499                                          adamgryu
# 3500                                          animdude
# 3501                        bitComposerEntertainmentAG
# 3502                                  bitComposerGames
# 3503                                               btf
# 3504                                           btfGmbH
# 3505                                       cleaversoft
# 3506                                           comcept
# 3507                                            d3tLtd
# 3508                                      damiansommer
# 3509                                    differentcloth
# 3510                                            doBell
# 3511                                         dreamfeel
# 3512                                        droolGames
# 3513                                         eSimGames
# 3514                                           exDream
# 3515                                            exozet
# 3516                                         frecleApS
# 3517                                              fyto
# 3518                                      h.a.n.d.Inc.
# 3519                                       i-illusions
# 3520                                          iFun4all
# 3521                                        iNKStories
# 3522                                              iNiS
# 3523                                  iRockInteractive
# 3524                                     iSquaredGames
# 3525                                              iWin
# 3526                                        idSoftware
# 3527                                      imaginarylab
# 3528                                    impressionware
# 3529                                    inbetweengames
# 3530                                         increpare
# 3531                                        indieszero
# 3532                                             inkle
# 3533                                        klutzGames
# 3534                                        machineboy
# 3535                                            miHoYo
# 3536                                           mif2000
# 3537                                           n-Space
# 3538                                           nDreams
# 3539                                              nWay
# 3540                                       neoSoftware
# 3541                                             neoqb
# 3542                                           nifflas
# 3543                                      odenisstudio
# 3544                                             oeFun
# 3545                                         osaogames
# 3546                                             roll7
# 3547                                      sebagamesdev
# 3548                                 stillalivestudios
# 3549                                    superflatgames
# 3550                                         synSophia
# 3551                                            teamok
# 3552                                   teedoubleuGAMES
# 3553                                       tiger&squid
# 3554                                      timesymmetry
# 3555                                         tinyBuild
# 3556                                    tinyBuildGAMES
# 3557                                           tobyfox
# 3558                                       winterworks
# 3559                                          xiigames
# 3560                                               yeo
# 3561                                            zSlide

# %% [markdown]
# Creamos un dataframe para determinar los desarrolladores con más de 10 juegos en la base de datos.

# %%
df_developers_count_more_than_50 = df_developers_count[df_developers_count >= 10]
df_developer_count_made = pd.DataFrame(df_developers_count_more_than_50, columns=['developer'])
df_developer_count_made.index.names = ['developer']
df_developer_count_made = df_developer_count_made.rename(columns={
    'developer': 'count'
})
df_developer_count_made
# Out:
#                                    count
# developer
# Capcom                               322
# TelltaleGames                        243
# EASports                             203
# Nintendo                             186
# Konami                               185
# EACanada                             180
# Ubisoft                              164
# UbisoftMontreal                      147
# SquareEnix                           129
# ElectronicArts                       107
# Codemasters                          104
# OmegaForce                           101
# EATiburon                            101
# Sega                                  99
# VisualConcepts                        87
# BandaiNamcoGames                      85
# Traveller'sTales                      82
# VicariousVisions                      77
# Namco                                 71
# Treyarch                              71
# FromSoftware                          70
# Midway                                66
# ArcSystemWorks                        64
# Rebellion                             64
# Yuke's                                63
# BioWare                               63
# Team17                                62
# GearboxSoftware                       62
# MilestoneS.r.l                        61
# DigitalEclipse                        60
# SonicTeam                             58
# ArtificialMindandMovement             57
# WayForward                            57
# Maxis                                 57
# EurocomEntertainmentSoftware          55
# ZenStudios                            54
# NipponIchiSoftware                    53
# ClimaxGroup                           53
# TTGames                               52
# HighVoltageSoftware                   52
# SumoDigital                           51
# NamcoBandaiGames                      51
# HarmonixMusicSystems                  50
# NeversoftEntertainment                50
# EADICE                                48
# Level5                                47
# IoInteractive                         47
# CreativeAssembly                      46
# BackboneEntertainment                 45
# TeamNinja                             45
# VolitionInc.                          44
# Cyanide                               44
# TaitoCorporation                      44
# DONTNODEntertainment                  44
# DoubleFineProductions                 43
# ObsidianEntertainment                 42
# RadicalEntertainment                  42
# TOSE                                  42
# AvalancheSoftware                     41
# CrystalDynamics                       41
# CyberConnect2                         41
# LucasArts                             41
# KromeStudios                          40
# Techland                              40
# BethesdaGameStudios                   40
# Gust                                  40
# FiraxisGames                          40
# Beenox                                40
# Atlus                                 39
# BlizzardEntertainment                 39
# IntelligentSystems                    39
# GameFreak                             39
# Acclaim                               38
# TerminalReality                       37
# CriterionGames                        37
# DimpsCorporation                      37
# Falcom                                37
# UbisoftMontpellier                    37
# Koei                                  36
# SaberInteractive                      35
# PandemicStudios                       35
# RainbowStudios                        35
# MonolithProductions                   34
# RareLtd.                              34
# FrontierDevelopments                  34
# InfinityWard                          34
# No info                               33
# ParadoxDevelopmentStudio              33
# PlatinumGames                         33
# KCET                                  33
# DoubleHelixGames                      32
# idSoftware                            31
# EALA                                  31
# 3DO                                   30
# EAGames                               30
# InsomniacGames                        30
# PopCap                                30
# DaedalicEntertainment                 30
# UbisoftParis                          30
# ValveSoftware                         30
# SNKPlaymore                           30
# SCEASanDiegoStudios                   29
# SCEJapanStudio                        29
# SpikeChunsoft                         28
# CompileHeart                          28
# IntiCreates                           28
# SCEELondonStudio                      28
# KushGames                             28
# SonyOnlineEntertainment               28
# UbisoftShanghai                       28
# AmazeEntertainment                    27
# THQ                                   27
# BlitzGames                            27
# GriptoniteGames                       27
# SCEA                                  27
# RockstarSanDiego                      27
# Tecmo                                 26
# HeavyIronStudios                      26
# Eutechnyx                             26
# EARedwoodShores                       26
# RavenSoftware                         25
# HALLabs                               25
# StainlessGames                        25
# Acquire                               25
# ArkaneStudios                         25
# MicrosoftGameStudios                  25
# PointofView                           24
# 989Sports                             24
# InXileEntertainment                   24
# EdgeofReality                         24
# ToysforBob                            23
# GrasshopperManufacture                23
# AvalancheStudios                      23
# Hudson                                23
# Frogwares                             23
# WalesInteractiveLtd.                  22
# KoeiTecmoGames                        22
# Kylotonn                              22
# BizarreCreations                      22
# EpicGames                             22
# RedStormEntertainment                 22
# Relic                                 21
# Gameloft                              21
# DigitalExtremes                       21
# IronGalaxyStudios                     21
# EABrightLight                         21
# Spike                                 21
# CityInteractive                       21
# Frozenbyte                            20
# HBStudiosMultimedia                   20
# SportsInteractive                     20
# SquareSoft                            20
# ACETeam                               20
# Activision                            20
# NinjaTheory                           20
# ViciousCycle                          20
# n-Space                               20
# GameArts                              20
# RockstarNorth                         20
# RyugaGotokuStudios                    19
# StormfrontStudios                     19
# RemedyEntertainment                   19
# Shin'en                               19
# Arika                                 19
# LionheadStudios                       19
# KCEJ                                  19
# Crytek                                19
# Kalypso                               19
# 11bitstudios                          19
# MassMedia                             19
# Starbreeze                            19
# BethesdaSoftworks                     19
# PipeworksSoftware                     19
# BlooberTeam                           18
# TwoTribes                             18
# ArgonautGames                         18
# Z-Axis                                18
# M2                                    18
# FatsharkAB                            18
# KojimaProductions                     18
# PivotalGames                          18
# Treasure                              18
# MonsterGamesInc.                      18
# CaviaInc.                             18
# Microids                              18
# ParadigmEntertainment                 18
# AsoboStudio                           18
# Funcom                                18
# BlueTongueEntertainment               18
# MercurySteam                          17
# Croteam                               17
# Bungie                                17
# Bugbear                               17
# Housemarque                           17
# NetherRealmStudios                    17
# NextLevelGames                        17
# ExientEntertainment                   17
# DigitalIllusions                      17
# HudsonSoft                            17
# Stardock                              17
# SegaAM2                               17
# VisceralGames                         17
# 7Studios                              17
# ZombieStudios                         17
# Tamsoft                               17
# NivalInteractive                      16
# GaijinEntertainment                   16
# IrrationalGames                       16
# Neverland                             16
# UbisoftQuebec                         16
# TheSimsStudio                         16
# GRIN                                  16
# Q-Games                               16
# NaughtyDog                            16
# HotheadGames                          16
# HighMoonStudios                       16
# CreatStudios                          16
# RedLynx                               16
# RocksteadyStudios                     16
# InfiniteInteractive                   16
# QEntertainment                        16
# Genki                                 16
# BlackBox                              16
# DrinkBoxStudios                       16
# EidosMontreal                         16
# EtrangesLibellules                    15
# DigitalReality                        15
# CDProjektRedStudio                    15
# SonyInteractiveEntertainment          15
# SlightlyMadStudios                    15
# Racjin                                15
# BigBadWolf                            15
# KleiEntertainment                     15
# SupermassiveGames                     15
# PiranhaBytes                          15
# 4AGames                               15
# MassiveEntertainment                  15
# KujuEntertainment                     15
# AbstractionGames                      15
# 4JStudios                             15
# SparkUnlimited                        15
# Haemimont                             15
# Tantalus                              15
# CamelotSoftwarePlanning               14
# MonolithSoft                          14
# Atari                                 14
# GSCGameWorld                          14
# NekoEntertainment                     14
# IdeaFactory                           14
# Image&Form                            14
# GaijinGames                           14
# Natsume                               14
# TorusGames                            14
# QuanticDream                          14
# UbisoftReflections                    14
# Luxoflux                              14
# NowProduction                         14
# BungieSoftware                        14
# LarianStudiosGames                    14
# JupiterCorporation                    14
# NeocoreGames                          14
# Mediatonic                            14
# MachineGames                          13
# 10tons                                13
# 2KSports                              13
# Ganbarion                             13
# SanzaruGames                          13
# KINGArt                               13
# ShabaGames                            13
# Nicalis                               13
# Eighting                              13
# Guerrilla                             13
# GameRepublic                          13
# EdenStudios                           13
# Deck13                                13
# UbisoftRomania                        13
# BlueCastleGames                       13
# BlackForestGames                      13
# 5pb                                   13
# GunfireGames                          13
# RevolutionSoftware                    13
# Sting                                 13
# AscaronEntertainmentGmbH              13
# MediaVision                           13
# Zoink!                                12
# BehaviourInteractive                  12
# 5THCell                               12
# Tri-Ace                               12
# Hitmaker                              12
# WowEntertainment                      12
# TimeGateStudios                       12
# BlackOpsEntertainment                 12
# FrictionalGames                       12
# SCEE                                  12
# Page44Studios                         12
# Warthog                               12
# RespawnEntertainment                  12
# TheOddGentlemen                       12
# FreeRadicalDesign                     12
# BohemiaInteractive                    12
# NixxesSoftware                        12
# AtlusCo.                              12
# ShinyEntertainment                    12
# RenegadeKid                           12
# GhostGames                            12
# EABlackBox                            12
# SecretLevel                           12
# TriumphStudios                        12
# RageSoftware                          12
# FuturLab                              11
# Wargaming.net                         11
# PyroStudios                           11
# CoreDesignLtd.                        11
# LiquidEntertainment                   11
# ProjectAces                           11
# Spiders                               11
# RealityPump                           11
# EugenSystems                          11
# MadDocSoftware                        11
# MonteCristoMultimedia                 11
# CapyGames                             11
# Hydravision                           11
# GiantsSoftware                        11
# Opus                                  11
# AttentionToDetail                     11
# Akella                                11
# 505Games                              11
# Teyon                                 11
# MatrixSoftware                        11
# SnowblindStudios                      11
# Stoic                                 11
# FirebrandGames                        11
# EnsembleStudios                       11
# HerInteractive                        11
# ZeniMaxMedia                          11
# AtomicPlanetEntertainment             11
# SupergiantGames                       11
# SledgehammerGames                     11
# CurveStudios                          10
# SidheInteractive                      10
# SouthendInteractive                   10
# PolyphonyDigital                      10
# DeckNineGames                         10
# BudCat                                10
# TheBehemoth                           10
# TripwireInteractive                   10
# GeniusSonorityInc.                    10
# BigAntStudios                         10
# CoffeeStainStudios                    10
# ZoeMode                               10
# PenduloStudios                        10
# Aspyr                                 10
# JustAddWater                          10
# ThunderLotusGames                     10
# TTFusion                              10
# ZipperInteractive                     10
# VooFooStudios                         10
# YachtClubGames                        10
# AcclaimStudiosCheltenham              10
# ThreeFieldsEntertainment              10
# ChunSoft                              10
# MikeBithell                           10
# CapcomVancouver                       10
# THQNordic                             10
# Irem                                  10
# Bandai                                10
# MarvelousEntertainment                10
# 1C                                    10
# Day1Studios                           10
# BossaStudios                          10
# FrimaStudio                           10
# GasPoweredGames                       10
# DeadlineGames                         10
# indieszero                            10
# Virtuos                               10
# PlaygroundGames                       10
# FreeStyleGames                        10
# KonamiComputerEntertainmentHawaii     10
# Petroglyph                            10

# %% [markdown]
# Obtenemos el número de juegos por plataforma y su "resumen" (promedio, mediana y desviación estándar)

# %%
df_summary_platforms = df_rewritten.groupby('platform')['score'].agg(['mean', 'median', 'std'])
df_summary_platforms
# Out:
#                       mean  median        std
# platform
# 3DS              69.607500    71.0  12.251068
# DS               66.480822    68.0  12.589991
# Dreamcast        73.696000    76.0  13.091011
# GameBoyAdvance   68.504505    70.0  13.052161
# GameCube         70.747788    71.0  12.868881
# Nintendo64       78.528571    81.0  13.242139
# PC               71.551394    73.0  11.765477
# PSP              68.493177    69.0  11.244115
# PlayStation      72.978723    75.5  15.939041
# PlayStation2     68.923836    70.0  12.662543
# PlayStation3     70.568164    72.0  13.262913
# PlayStation4     71.022303    72.0  11.038312
# PlayStation5     80.000000    82.0   6.244998
# PlayStationVita  70.980545    72.0  10.548049
# Stadia           76.750000    76.5   4.349329
# Switch           72.442959    74.0  10.274417
# Wii              65.707831    67.0  13.796262
# WiiU             72.021505    76.0  13.904678
# Xbox             69.972257    72.0  13.638431
# Xbox360          68.582833    71.0  14.093746
# XboxOne          72.352415    74.0  10.459846
# XboxSeriesX      85.500000    85.5   0.707107

# %%
df_count_platforms = df_rewritten.groupby('platform').size()
df_count_platforms = pd.DataFrame(df_count_platforms, columns=['count'])

# %%
df_summary_platforms_count = pd.concat([df_count_platforms,df_summary_platforms], axis=1)
df_summary_platforms_count
# Out:
#                  count       mean  median        std
# platform
# 3DS                400  69.607500    71.0  12.251068
# DS                 730  66.480822    68.0  12.589991
# Dreamcast          125  73.696000    76.0  13.091011
# GameBoyAdvance     444  68.504505    70.0  13.052161
# GameCube           452  70.747788    71.0  12.868881
# Nintendo64          70  78.528571    81.0  13.242139
# PC                4592  71.551394    73.0  11.765477
# PSP                513  68.493177    69.0  11.244115
# PlayStation        188  72.978723    75.5  15.939041
# PlayStation2      1418  68.923836    70.0  12.662543
# PlayStation3      1269  70.568164    72.0  13.262913
# PlayStation4      1928  71.022303    72.0  11.038312
# PlayStation5         3  80.000000    82.0   6.244998
# PlayStationVita    257  70.980545    72.0  10.548049
# Stadia               4  76.750000    76.5   4.349329
# Switch            1122  72.442959    74.0  10.274417
# Wii                664  65.707831    67.0  13.796262
# WiiU               186  72.021505    76.0  13.904678
# Xbox               793  69.972257    72.0  13.638431
# Xbox360           1666  68.582833    71.0  14.093746
# XboxOne           1118  72.352415    74.0  10.459846
# XboxSeriesX          2  85.500000    85.5   0.707107

# %% [markdown]
# Eliminamos las plataformas que tengan menos de 10 juegos en la lista.

# %%
df_summary_platforms_count.drop(df_summary_platforms_count[(df_summary_platforms_count['count'] < 10)].index, inplace=True)
df_summary_platforms_count
# Out:
#                  count       mean  median        std
# platform
# 3DS                400  69.607500    71.0  12.251068
# DS                 730  66.480822    68.0  12.589991
# Dreamcast          125  73.696000    76.0  13.091011
# GameBoyAdvance     444  68.504505    70.0  13.052161
# GameCube           452  70.747788    71.0  12.868881
# Nintendo64          70  78.528571    81.0  13.242139
# PC                4592  71.551394    73.0  11.765477
# PSP                513  68.493177    69.0  11.244115
# PlayStation        188  72.978723    75.5  15.939041
# PlayStation2      1418  68.923836    70.0  12.662543
# PlayStation3      1269  70.568164    72.0  13.262913
# PlayStation4      1928  71.022303    72.0  11.038312
# PlayStationVita    257  70.980545    72.0  10.548049
# Switch            1122  72.442959    74.0  10.274417
# Wii                664  65.707831    67.0  13.796262
# WiiU               186  72.021505    76.0  13.904678
# Xbox               793  69.972257    72.0  13.638431
# Xbox360           1666  68.582833    71.0  14.093746
# XboxOne           1118  72.352415    74.0  10.459846

# %% [markdown]
# Checamos la aceptación que tienen los usuarios por compañía y consola.

# %%
df_count_companies_platforms = df_rewritten.groupby(['company','platform'])['user_score'].size()

# %%
df_summary_companies_platforms = df_rewritten.groupby(['company','platform'])['user_score'].agg(['mean', 'median', 'std'])
df_summary_companies_platforms
# Out:
#                                mean  median       std
# company   platform
# Desktop   PC               6.648824    7.10  1.822876
#           Stadia           5.375000    7.10  3.584573
# Microsoft Xbox             6.020050    7.30  2.984119
#           Xbox360          6.582353    7.10  1.917227
#           XboxOne          5.849106    6.50  2.243014
#           XboxSeriesX      0.000000    0.00  0.000000
# Nintendo  3DS              6.822750    7.40  1.724730
#           DS               5.600959    7.20  3.201892
#           GameBoyAdvance   5.809234    7.65  3.447370
#           GameCube         6.838496    7.80  2.457474
#           Nintendo64       8.080000    8.25  0.771710
#           Switch           6.425490    7.30  2.477573
#           Wii              6.482229    7.30  2.403583
#           WiiU             7.201075    7.50  1.306160
# SEGA      Dreamcast        7.696000    8.00  1.587928
# Sony      PSP              6.578363    7.40  2.469221
#           PlayStation      6.671809    7.95  3.016586
#           PlayStation2     7.019887    7.90  2.387408
#           PlayStation3     6.657210    7.10  1.754028
#           PlayStation4     6.145280    6.60  1.858742
#           PlayStation5     0.000000    0.00  0.000000
#           PlayStationVita  7.143580    7.40  1.377089

# %%
df_summary_platforms_companies_count = pd.concat([df_summary_companies_platforms,df_count_companies_platforms], axis=1)
df_summary_platforms_companies_count= df_summary_platforms_companies_count.rename(columns={
    'user_score': 'count'
})
df_summary_platforms_companies_count.drop(df_summary_platforms_companies_count[(df_summary_platforms_companies_count['count'] < 10)].index, inplace=True)
df_summary_platforms_companies_count
# Out:
#                                mean  median       std  count
# company   platform
# Desktop   PC               6.648824    7.10  1.822876   4592
# Microsoft Xbox             6.020050    7.30  2.984119    793
#           Xbox360          6.582353    7.10  1.917227   1666
#           XboxOne          5.849106    6.50  2.243014   1118
# Nintendo  3DS              6.822750    7.40  1.724730    400
#           DS               5.600959    7.20  3.201892    730
#           GameBoyAdvance   5.809234    7.65  3.447370    444
#           GameCube         6.838496    7.80  2.457474    452
#           Nintendo64       8.080000    8.25  0.771710     70
#           Switch           6.425490    7.30  2.477573   1122
#           Wii              6.482229    7.30  2.403583    664
#           WiiU             7.201075    7.50  1.306160    186
# SEGA      Dreamcast        7.696000    8.00  1.587928    125
# Sony      PSP              6.578363    7.40  2.469221    513
#           PlayStation      6.671809    7.95  3.016586    188
#           PlayStation2     7.019887    7.90  2.387408   1418
#           PlayStation3     6.657210    7.10  1.754028   1269
#           PlayStation4     6.145280    6.60  1.858742   1928
#           PlayStationVita  7.143580    7.40  1.377089    257
